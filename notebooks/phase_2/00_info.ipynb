# %% [markdown]
# # LSTM + GRU Hybrid Model for Stock Prediction

# %%
# Load Phase-1 artifacts inside Phase-2 notebook
from pathlib import Path
import joblib
import numpy as np

root = Path.cwd()
while root != root.parent and not (root / "data").exists():
    root = root.parent

art_dir = root / "data" / "processed"
artifacts = joblib.load(art_dir / "phase1_preprocessing_artifacts.joblib")

scaler = artifacts["scaler"]
pca = artifacts["pca"]
feature_cols = artifacts["feature_cols"]

# %%
#check what datatype scaler is
print(type(scaler))
print(type(pca))
print(feature_cols)
# Out:
# <class 'sklearn.preprocessing._data.StandardScaler'>
# <class 'sklearn.decomposition._pca.PCA'>
# ['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'adj_close', 'logret_1d', 'ret_1d', 'hl_range', 'oc_change', 'ret_mean_5', 'ret_vol_5', 'ret_mean_10', 'ret_vol_10', 'ret_mean_20', 'ret_vol_20', 'ret_mean_60', 'ret_vol_60', 'sma_5', 'sma_10', 'sma_20', 'sma_60', 'sma_spread_5', 'sma_spread_20', 'sma_spread_60', 'ema_12', 'ema_26', 'macd', 'macd_signal', 'macd_hist', 'rsi_14', 'bb_mid_20', 'bb_std_20', 'bb_upper_20', 'bb_lower_20', 'bb_width_20', 'vol_change', 'vol_z_20', 'obv', 'dow', 'month', 'is_month_end', 'logret_1d_lag1', 'logret_1d_lag2', 'logret_1d_lag3', 'logret_1d_lag4', 'logret_1d_lag5', 'logret_1d_lag6', 'logret_1d_lag7', 'logret_1d_lag8', 'logret_1d_lag9', 'logret_1d_lag10', 'logret_1d_lag11', 'logret_1d_lag12', 'logret_1d_lag13', 'logret_1d_lag14', 'logret_1d_lag15', 'logret_1d_lag16', 'logret_1d_lag17', 'logret_1d_lag18', 'logret_1d_lag19', 'logret_1d_lag20', 'logret_1d_lag21', 'logret_1d_lag22', 'logret_1d_lag23', 'logret_1d_lag24', 'logret_1d_lag25', 'logret_1d_lag26', 'logret_1d_lag27', 'logret_1d_lag28', 'logret_1d_lag29', 'logret_1d_lag30', 'logret_1d_lag31', 'logret_1d_lag32', 'logret_1d_lag33', 'logret_1d_lag34', 'logret_1d_lag35', 'logret_1d_lag36', 'logret_1d_lag37', 'logret_1d_lag38', 'logret_1d_lag39', 'logret_1d_lag40', 'logret_1d_lag41', 'logret_1d_lag42', 'logret_1d_lag43', 'logret_1d_lag44', 'logret_1d_lag45', 'logret_1d_lag46', 'logret_1d_lag47', 'logret_1d_lag48', 'logret_1d_lag49', 'logret_1d_lag50', 'logret_1d_lag51', 'logret_1d_lag52', 'logret_1d_lag53', 'logret_1d_lag54', 'logret_1d_lag55', 'logret_1d_lag56', 'logret_1d_lag57', 'logret_1d_lag58', 'logret_1d_lag59', 'logret_1d_lag60', 'AAPL_logret_lag1', 'CL=F_logret_lag1', 'GC=F_logret_lag1', 'QQQ_logret_lag1', 'SPY_logret_lag1', 'UUP_logret_lag1', 'XLK_logret_lag1', '^TNX_logret_lag1', '^VIX_logret_lag1', 'AAPL_logret_lag2', 'CL=F_logret_lag2', 'GC=F_logret_lag2', 'QQQ_logret_lag2', 'SPY_logret_lag2', 'UUP_logret_lag2', 'XLK_logret_lag2', '^TNX_logret_lag2', '^VIX_logret_lag2', 'AAPL_logret_lag3', 'CL=F_logret_lag3', 'GC=F_logret_lag3', 'QQQ_logret_lag3', 'SPY_logret_lag3', 'UUP_logret_lag3', 'XLK_logret_lag3', '^TNX_logret_lag3', '^VIX_logret_lag3', 'AAPL_logret_lag4', 'CL=F_logret_lag4', 'GC=F_logret_lag4', 'QQQ_logret_lag4', 'SPY_logret_lag4', 'UUP_logret_lag4', 'XLK_logret_lag4', '^TNX_logret_lag4', '^VIX_logret_lag4', 'AAPL_logret_lag5', 'CL=F_logret_lag5', 'GC=F_logret_lag5', 'QQQ_logret_lag5', 'SPY_logret_lag5', 'UUP_logret_lag5', 'XLK_logret_lag5', '^TNX_logret_lag5', '^VIX_logret_lag5', 'AAPL_logret_lag6', 'CL=F_logret_lag6', 'GC=F_logret_lag6', 'QQQ_logret_lag6', 'SPY_logret_lag6', 'UUP_logret_lag6', 'XLK_logret_lag6', '^TNX_logret_lag6', '^VIX_logret_lag6', 'AAPL_logret_lag7', 'CL=F_logret_lag7', 'GC=F_logret_lag7', 'QQQ_logret_lag7', 'SPY_logret_lag7', 'UUP_logret_lag7', 'XLK_logret_lag7', '^TNX_logret_lag7', '^VIX_logret_lag7', 'AAPL_logret_lag8', 'CL=F_logret_lag8', 'GC=F_logret_lag8', 'QQQ_logret_lag8', 'SPY_logret_lag8', 'UUP_logret_lag8', 'XLK_logret_lag8', '^TNX_logret_lag8', '^VIX_logret_lag8', 'AAPL_logret_lag9', 'CL=F_logret_lag9', 'GC=F_logret_lag9', 'QQQ_logret_lag9', 'SPY_logret_lag9', 'UUP_logret_lag9', 'XLK_logret_lag9', '^TNX_logret_lag9', '^VIX_logret_lag9', 'AAPL_logret_lag10', 'CL=F_logret_lag10', 'GC=F_logret_lag10', 'QQQ_logret_lag10', 'SPY_logret_lag10', 'UUP_logret_lag10', 'XLK_logret_lag10', '^TNX_logret_lag10', '^VIX_logret_lag10', 'AAPL_logret_lag11', 'CL=F_logret_lag11', 'GC=F_logret_lag11', 'QQQ_logret_lag11', 'SPY_logret_lag11', 'UUP_logret_lag11', 'XLK_logret_lag11', '^TNX_logret_lag11', '^VIX_logret_lag11', 'AAPL_logret_lag12', 'CL=F_logret_lag12', 'GC=F_logret_lag12', 'QQQ_logret_lag12', 'SPY_logret_lag12', 'UUP_logret_lag12', 'XLK_logret_lag12', '^TNX_logret_lag12', '^VIX_logret_lag12', 'AAPL_logret_lag13', 'CL=F_logret_lag13', 'GC=F_logret_lag13', 'QQQ_logret_lag13', 'SPY_logret_lag13', 'UUP_logret_lag13', 'XLK_logret_lag13', '^TNX_logret_lag13', '^VIX_logret_lag13', 'AAPL_logret_lag14', 'C ...

# %%
artifacts.keys()
# Out:
# dict_keys(['scaler', 'pca', 'feature_cols', 'target_col', 'top_exog', 'pca_feature_cols', 'drop_cols'])

# %%
#cell 1: imports + project paths
from pathlib import Path
import numpy as np
import pandas as pd

cwd = Path.cwd().resolve()
project_root = None
for p in [cwd] + list(cwd.parents):
    if (p / "data").exists():
        project_root = p
        break
if project_root is None:
    raise RuntimeError("Project root not found: missing /data folder")

DATA_DIR = project_root / "data"
PROC_DIR = DATA_DIR / "processed"

panel_path = PROC_DIR / "modeling_panel_targets.parquet"
print("project_root:", project_root)
print("panel_path:", panel_path)
# Out:
# project_root: /media/workhorse/Windows/MyWorkPlace/Projects/StockPredictor
# panel_path: /media/workhorse/Windows/MyWorkPlace/Projects/StockPredictor/data/processed/modeling_panel_targets.parquet

# %%
#cell 2: load + filter AAPL + clean column names
df = pd.read_parquet(panel_path)
df["date"] = pd.to_datetime(df["date"])

df = df.sort_values(["ticker", "date"]).reset_index(drop=True)
df = df[df["ticker"] == "AAPL"].copy()
df = df.sort_values("date").reset_index(drop=True)

#fix repeated substring in exog lag columns
df.columns = (
    pd.Index(df.columns)
    .str.replace("_logret_laglogret_lag", "_logret_lag", regex=False)
)

#drop all columns related to other tickers
cols_to_drop = [col for col in df.columns if col.startswith(("MSFT_", "GOOG_", "AMZN_"))]
df = df.drop(columns=cols_to_drop)

print("AAPL df shape:", df.shape)
df.head(3)
# Out:
# AAPL df shape: (3285, 286)
#         date ticker       Open       High        Low      Close  Adj Close  \
# 0 2013-01-02   AAPL  19.779285  19.821428  19.343929  19.608213  16.612209
# 1 2013-01-03   AAPL  19.567142  19.631071  19.321428  19.360714  16.402523
# 2 2013-01-04   AAPL  19.177500  19.236786  18.779642  18.821428  15.945646
#
#         Volume  adj_close  logret_1d  ...  ^VIX_logret_lag19  \
# 0  560518000.0  16.612209        NaN  ...                NaN
# 1  352965200.0  16.402523  -0.012703  ...                NaN
# 2  594333600.0  15.945646  -0.028249  ...                NaN
#
#    AAPL_logret_lag20  CL=F_logret_lag20  GC=F_logret_lag20  QQQ_logret_lag20  \
# 0                NaN                NaN                NaN               NaN
# 1                NaN                NaN                NaN               NaN
# 2                NaN                NaN                NaN               NaN
#
#    SPY_logret_lag20  UUP_logret_lag20  XLK_logret_lag20  ^TNX_logret_lag20  \
# 0               NaN               NaN               NaN                NaN
# 1               NaN               NaN               NaN                NaN
# 2               NaN               NaN               NaN                NaN
#
#    ^VIX_logret_lag20
# 0                NaN
# 1                NaN
# 2                NaN
#
# [3 rows x 286 columns]

# %%
#print all columns with NaN values and counts in descending
print("Columns with NaN values:")
print(df.isna().sum()[df.isna().sum() > 0].sort_values(ascending=False))
# Out:
# Columns with NaN values:
# logret_1d_lag60     61
# logret_1d_lag59     60
# ret_mean_60         60
# ret_vol_60          60
# logret_1d_lag58     59
#                     ..
# AAPL_logret_lag1     2
# vol_change           1
# ret_1d               1
# target_logret_1d     1
# logret_1d            1
# Length: 266, dtype: int64

# %%
#print the column names
print("Column names:")
print(df.columns.tolist())
# Out:
# Column names:
# ['date', 'ticker', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'adj_close', 'logret_1d', 'ret_1d', 'target_logret_1d', 'hl_range', 'oc_change', 'ret_mean_5', 'ret_vol_5', 'ret_mean_10', 'ret_vol_10', 'ret_mean_20', 'ret_vol_20', 'ret_mean_60', 'ret_vol_60', 'sma_5', 'sma_10', 'sma_20', 'sma_60', 'sma_spread_5', 'sma_spread_20', 'sma_spread_60', 'ema_12', 'ema_26', 'macd', 'macd_signal', 'macd_hist', 'rsi_14', 'bb_mid_20', 'bb_std_20', 'bb_upper_20', 'bb_lower_20', 'bb_width_20', 'vol_change', 'vol_z_20', 'obv', 'dow', 'month', 'is_month_end', 'logret_1d_lag1', 'logret_1d_lag2', 'logret_1d_lag3', 'logret_1d_lag4', 'logret_1d_lag5', 'logret_1d_lag6', 'logret_1d_lag7', 'logret_1d_lag8', 'logret_1d_lag9', 'logret_1d_lag10', 'logret_1d_lag11', 'logret_1d_lag12', 'logret_1d_lag13', 'logret_1d_lag14', 'logret_1d_lag15', 'logret_1d_lag16', 'logret_1d_lag17', 'logret_1d_lag18', 'logret_1d_lag19', 'logret_1d_lag20', 'logret_1d_lag21', 'logret_1d_lag22', 'logret_1d_lag23', 'logret_1d_lag24', 'logret_1d_lag25', 'logret_1d_lag26', 'logret_1d_lag27', 'logret_1d_lag28', 'logret_1d_lag29', 'logret_1d_lag30', 'logret_1d_lag31', 'logret_1d_lag32', 'logret_1d_lag33', 'logret_1d_lag34', 'logret_1d_lag35', 'logret_1d_lag36', 'logret_1d_lag37', 'logret_1d_lag38', 'logret_1d_lag39', 'logret_1d_lag40', 'logret_1d_lag41', 'logret_1d_lag42', 'logret_1d_lag43', 'logret_1d_lag44', 'logret_1d_lag45', 'logret_1d_lag46', 'logret_1d_lag47', 'logret_1d_lag48', 'logret_1d_lag49', 'logret_1d_lag50', 'logret_1d_lag51', 'logret_1d_lag52', 'logret_1d_lag53', 'logret_1d_lag54', 'logret_1d_lag55', 'logret_1d_lag56', 'logret_1d_lag57', 'logret_1d_lag58', 'logret_1d_lag59', 'logret_1d_lag60', 'AAPL_logret_lag1', 'CL=F_logret_lag1', 'GC=F_logret_lag1', 'QQQ_logret_lag1', 'SPY_logret_lag1', 'UUP_logret_lag1', 'XLK_logret_lag1', '^TNX_logret_lag1', '^VIX_logret_lag1', 'AAPL_logret_lag2', 'CL=F_logret_lag2', 'GC=F_logret_lag2', 'QQQ_logret_lag2', 'SPY_logret_lag2', 'UUP_logret_lag2', 'XLK_logret_lag2', '^TNX_logret_lag2', '^VIX_logret_lag2', 'AAPL_logret_lag3', 'CL=F_logret_lag3', 'GC=F_logret_lag3', 'QQQ_logret_lag3', 'SPY_logret_lag3', 'UUP_logret_lag3', 'XLK_logret_lag3', '^TNX_logret_lag3', '^VIX_logret_lag3', 'AAPL_logret_lag4', 'CL=F_logret_lag4', 'GC=F_logret_lag4', 'QQQ_logret_lag4', 'SPY_logret_lag4', 'UUP_logret_lag4', 'XLK_logret_lag4', '^TNX_logret_lag4', '^VIX_logret_lag4', 'AAPL_logret_lag5', 'CL=F_logret_lag5', 'GC=F_logret_lag5', 'QQQ_logret_lag5', 'SPY_logret_lag5', 'UUP_logret_lag5', 'XLK_logret_lag5', '^TNX_logret_lag5', '^VIX_logret_lag5', 'AAPL_logret_lag6', 'CL=F_logret_lag6', 'GC=F_logret_lag6', 'QQQ_logret_lag6', 'SPY_logret_lag6', 'UUP_logret_lag6', 'XLK_logret_lag6', '^TNX_logret_lag6', '^VIX_logret_lag6', 'AAPL_logret_lag7', 'CL=F_logret_lag7', 'GC=F_logret_lag7', 'QQQ_logret_lag7', 'SPY_logret_lag7', 'UUP_logret_lag7', 'XLK_logret_lag7', '^TNX_logret_lag7', '^VIX_logret_lag7', 'AAPL_logret_lag8', 'CL=F_logret_lag8', 'GC=F_logret_lag8', 'QQQ_logret_lag8', 'SPY_logret_lag8', 'UUP_logret_lag8', 'XLK_logret_lag8', '^TNX_logret_lag8', '^VIX_logret_lag8', 'AAPL_logret_lag9', 'CL=F_logret_lag9', 'GC=F_logret_lag9', 'QQQ_logret_lag9', 'SPY_logret_lag9', 'UUP_logret_lag9', 'XLK_logret_lag9', '^TNX_logret_lag9', '^VIX_logret_lag9', 'AAPL_logret_lag10', 'CL=F_logret_lag10', 'GC=F_logret_lag10', 'QQQ_logret_lag10', 'SPY_logret_lag10', 'UUP_logret_lag10', 'XLK_logret_lag10', '^TNX_logret_lag10', '^VIX_logret_lag10', 'AAPL_logret_lag11', 'CL=F_logret_lag11', 'GC=F_logret_lag11', 'QQQ_logret_lag11', 'SPY_logret_lag11', 'UUP_logret_lag11', 'XLK_logret_lag11', '^TNX_logret_lag11', '^VIX_logret_lag11', 'AAPL_logret_lag12', 'CL=F_logret_lag12', 'GC=F_logret_lag12', 'QQQ_logret_lag12', 'SPY_logret_lag12', 'UUP_logret_lag12', 'XLK_logret_lag12', '^TNX_logret_lag12', '^VIX_logret_lag12', 'AAPL_logret_lag13', 'CL=F_logret_lag13', 'GC=F_logret_lag13', 'QQQ_logret_lag13', 'SPY_logret_lag13', 'UUP_logret_lag13', 'XLK_logret_lag13', '^TNX_logret_lag13', '^VIX_ ...

# %%
#cell 3: define X/y and time split
TARGET = "target_logret_1d"

drop_cols = {
    "date", "ticker",
    TARGET,
}

#keep numeric predictors only
num_cols = df.select_dtypes(include=[np.number]).columns.tolist()
feature_cols = [c for c in num_cols if c not in drop_cols]

#drop rows with missing target or missing features
model_df = df[["date", TARGET] + feature_cols].dropna().reset_index(drop=True)

n = len(model_df)
split_idx = int(n * 0.80)

train_df = model_df.iloc[:split_idx].copy()
test_df  = model_df.iloc[split_idx:].copy()

X_train = train_df[feature_cols].copy()
y_train = train_df[TARGET].copy()

X_test  = test_df[feature_cols].copy()
y_test  = test_df[TARGET].copy()

print("model_df shape:", model_df.shape)
print("train rows:", len(train_df), "test rows:", len(test_df))
print("train date range:", train_df["date"].min(), "to", train_df["date"].max())
print("test  date range:", test_df["date"].min(), "to", test_df["date"].max())
# Out:
# model_df shape: (3097, 285)
# train rows: 2477 test rows: 620
# train date range: 2013-04-02 00:00:00 to 2023-06-01 00:00:00
# test  date range: 2023-06-02 00:00:00 to 2026-01-22 00:00:00

# %%
#cell 4: feature ranking diagnostics (train only)
from sklearn.feature_selection import mutual_info_regression

corr = pd.concat([X_train, y_train], axis=1).corr(numeric_only=True)[TARGET].drop(TARGET)
corr_rank = corr.abs().sort_values(ascending=False).head(25)

mi = mutual_info_regression(X_train.values, y_train.values, random_state=42)
mi_rank = pd.Series(mi, index=feature_cols).sort_values(ascending=False).head(25)

print("Top 25 by |corr|")
display(corr_rank.to_frame("abs_corr"))

print("Top 25 by mutual information")
display(mi_rank.to_frame("mi"))
# Out:
# Top 25 by |corr|
#                   abs_corr
# XLK_logret_lag7   0.108424
# QQQ_logret_lag7   0.107897
# SPY_logret_lag7   0.107107
# XLK_logret_lag6   0.103955
# logret_1d_lag7    0.097293
# AAPL_logret_lag7  0.097293
# SPY_logret_lag6   0.097103
# QQQ_logret_lag6   0.096027
# SPY_logret_lag8   0.090016
# QQQ_logret_lag14  0.086478
# logret_1d_lag8    0.085158
# AAPL_logret_lag8  0.085158
# SPY_logret_lag14  0.083550
# XLK_logret_lag8   0.082473
# XLK_logret_lag14  0.081106
# SPY_logret_lag5   0.080272
# logret_1d_lag6    0.079410
# AAPL_logret_lag6  0.079410
# XLK_logret_lag5   0.079401
# QQQ_logret_lag8   0.078910
# ^TNX_logret_lag8  0.073293
# QQQ_logret_lag5   0.073257
# ret_1d            0.067552
# logret_1d         0.067485
# ^VIX_logret_lag7  0.066059
# Top 25 by mutual information
#                         mi
# ret_vol_10        0.058560
# hl_range          0.055978
# ret_1d            0.055113
# logret_1d         0.053923
# sma_5             0.051344
# macd              0.047551
# High              0.038625
# rsi_14            0.035834
# ^VIX_logret_lag4  0.034488
# Close             0.032971
# ret_mean_20       0.032621
# SPY_logret_lag11  0.032286
# XLK_logret_lag19  0.032057
# sma_spread_60     0.031476
# ret_vol_60        0.031423
# GC=F_logret_lag2  0.030983
# sma_60            0.030969
# bb_upper_20       0.030885
# logret_1d_lag31   0.030805
# adj_close         0.030020
# bb_std_20         0.030018
# Adj Close         0.029977
# Open              0.029907
# ret_mean_5        0.029627
# sma_spread_5      0.029449

# %%
#cell 5: PCA explained variance diagnostic
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

scaler = StandardScaler()
X_train_s = scaler.fit_transform(X_train.values)
X_test_s  = scaler.transform(X_test.values)

pca = PCA(n_components=0.80, svd_solver="full")
X_train_p = pca.fit_transform(X_train_s)
X_test_p  = pca.transform(X_test_s)

print("PCA components for 80% variance:", pca.n_components_)
print("Explained variance ratio sum:", pca.explained_variance_ratio_.sum())
# Out:
# PCA components for 80% variance: 91
# Explained variance ratio sum: 0.8022804105397852

# %%
#print the columns in X_train_p
pca_columns = [f"pca_{i+1}" for i in range(pca.n_components_)]
print("PCA feature columns:", pca_columns)
# Out:
# PCA feature columns: ['pca_1', 'pca_2', 'pca_3', 'pca_4', 'pca_5', 'pca_6', 'pca_7', 'pca_8', 'pca_9', 'pca_10', 'pca_11', 'pca_12', 'pca_13', 'pca_14', 'pca_15', 'pca_16', 'pca_17', 'pca_18', 'pca_19', 'pca_20', 'pca_21', 'pca_22', 'pca_23', 'pca_24', 'pca_25', 'pca_26', 'pca_27', 'pca_28', 'pca_29', 'pca_30', 'pca_31', 'pca_32', 'pca_33', 'pca_34', 'pca_35', 'pca_36', 'pca_37', 'pca_38', 'pca_39', 'pca_40', 'pca_41', 'pca_42', 'pca_43', 'pca_44', 'pca_45', 'pca_46', 'pca_47', 'pca_48', 'pca_49', 'pca_50', 'pca_51', 'pca_52', 'pca_53', 'pca_54', 'pca_55', 'pca_56', 'pca_57', 'pca_58', 'pca_59', 'pca_60', 'pca_61', 'pca_62', 'pca_63', 'pca_64', 'pca_65', 'pca_66', 'pca_67', 'pca_68', 'pca_69', 'pca_70', 'pca_71', 'pca_72', 'pca_73', 'pca_74', 'pca_75', 'pca_76', 'pca_77', 'pca_78', 'pca_79', 'pca_80', 'pca_81', 'pca_82', 'pca_83', 'pca_84', 'pca_85', 'pca_86', 'pca_87', 'pca_88', 'pca_89', 'pca_90', 'pca_91']

# %%
#cell: PCA loadings (which original features drive each component)
loadings = pd.DataFrame(
    pca.components_,
    columns=feature_cols,
    index=[f"pca_{i+1}" for i in range(pca.n_components_)]
)

def top_loadings(component_name, k=10):
    s = loadings.loc[component_name].abs().sort_values(ascending=False).head(k)
    return s

print("Top 10 original features for pca_1")
display(top_loadings("pca_1", 10).to_frame("abs_loading"))

print("Top 10 original features for pca_2")
display(top_loadings("pca_2", 10).to_frame("abs_loading"))
# Out:
# Top 10 original features for pca_1
#              abs_loading
# bb_upper_20     0.241004
# ema_12          0.240628
# sma_10          0.240588
# ema_26          0.240551
# sma_20          0.240532
# bb_mid_20       0.240532
# sma_5           0.240531
# High            0.240523
# Open            0.240417
# adj_close       0.240411
# Top 10 original features for pca_2
#                abs_loading
# sma_spread_20     0.274255
# ret_mean_20       0.270796
# rsi_14            0.265498
# sma_spread_60     0.261440
# ret_mean_10       0.243044
# macd              0.224651
# ret_mean_5        0.197022
# macd_signal       0.185618
# ret_mean_60       0.183355
# sma_spread_5      0.165674

# %%
# Cell 14: Comprehensive Dataset & PCA Information for LLM Understanding
print("=" * 80)
print("COMPLETE DATASET AND PCA INFORMATION")
print("=" * 80)

# ============================================================================
# 1. DATASET OVERVIEW (INCLUDES DATE INDEX)
# ============================================================================
print("\n" + "="*80)
print("1. DATASET OVERVIEW")
print("="*80)
print("Dataset: AAPL Stock Price Prediction")
print(f"Target Variable: {TARGET}")
print("Index Column: date (preserved as a datetime column, used for temporal ordering)")
print(f"Total Rows (after dropna): {len(model_df):,}")
print(f"Total Original Features (excluding date and target): {len(feature_cols)}")
print("\nTrain/Test Split (80/20 temporal split):")
print(f"  - Training rows: {len(train_df):,} ({len(train_df)/len(model_df)*100:.1f}%)")
print(f"  - Test rows: {len(test_df):,} ({len(test_df)/len(model_df)*100:.1f}%)")
print(f"  - Train date range: {train_df['date'].min().date()} to {train_df['date'].max().date()}")
print(f"  - Test date range: {test_df['date'].min().date()} to {test_df['date'].max().date()}")

# ============================================================================
# 2. INDEX (DATE) DETAILS
# ============================================================================
print("\n" + "="*80)
print("2. INDEX (DATE) DETAILS")
print("="*80)
print("Date column retained (not dropped) to preserve temporal index.")
print(f"  - Unique dates: {model_df['date'].nunique():,}")
print(f"  - Min date: {model_df['date'].min().date()}")
print(f"  - Max date: {model_df['date'].max().date()}")
# Approximate dominant frequency
if len(model_df) > 1:
    day_diffs = model_df['date'].diff().dt.days.dropna()
    if not day_diffs.empty:
        dominant_freq = day_diffs.mode().iloc[0]
        print(f"  - Dominant gap between rows (days): {dominant_freq}")
    else:
        print("  - Dominant gap between rows (days): n/a")
else:
    print("  - Dominant gap between rows (days): n/a")

# ============================================================================
# 3. FEATURE INFORMATION
# ============================================================================
print("\n" + "="*80)
print("3. FEATURE INFORMATION")
print("="*80)
print(f"Total number of numeric features (excludes date and target): {len(feature_cols)}")
print(f"\nAll columns including index and target ({len(feature_cols)+2} columns):")
all_cols_with_index = ["date (index)"] + feature_cols + [TARGET]
for i, col in enumerate(all_cols_with_index, 1):
    print(f"  {i:3d}. {col}")

print(f"\nFeature names only ({len(feature_cols)} features):")
for i, col in enumerate(feature_cols, 1):
    print(f"  {i:3d}. {col}")

print(f"\n--- Training Data Feature Statistics (numeric features only) ---")
train_stats = X_train.describe().T
print("Feature value ranges (min, max, mean, std):")
print(train_stats[['min', 'max', 'mean', 'std']].to_string())

# ============================================================================
# 4. TARGET VARIABLE INFORMATION
# ============================================================================
print("\n" + "="*80)
print("4. TARGET VARIABLE INFORMATION")
print("="*80)
print(f"Target: {TARGET}")
print("Description: Next day log return of AAPL stock")
print("\nTraining Target Statistics:")
print(f"  - Mean: {y_train.mean():.6f}")
print(f"  - Std: {y_train.std():.6f}")
print(f"  - Min: {y_train.min():.6f}")
print(f"  - Max: {y_train.max():.6f}")
print(f"  - Median: {y_train.median():.6f}")
print("\nTest Target Statistics:")
print(f"  - Mean: {y_test.mean():.6f}")
print(f"  - Std: {y_test.std():.6f}")
print(f"  - Min: {y_test.min():.6f}")
print(f"  - Max: {y_test.max():.6f}")
print(f"  - Median: {y_test.median():.6f}")

# ============================================================================
# 5. FEATURE IMPORTANCE & CORRELATION ANALYSIS
# ============================================================================
print("\n" + "="*80)
print("5. FEATURE IMPORTANCE & CORRELATION ANALYSIS")
print("="*80)
print("Top 25 Features by Absolute Correlation with Target:")
print(corr_rank.to_frame('abs_corr').to_string())

print("\nTop 25 Features by Mutual Information with Target:")
print(mi_rank.to_frame('mutual_info').to_string())

# ============================================================================
# 6. PCA TRANSFORMATION DETAILS
# ============================================================================
print("\n" + "="*80)
print("6. PCA TRANSFORMATION DETAILS")
print("="*80)
print("PCA Configuration:")
print("  - Variance retention threshold: 80%")
print("  - SVD solver: full")
print(f"  - Number of components selected: {pca.n_components_}")
print(f"  - Original feature dimension: {len(feature_cols)} (date excluded)")
print(f"  - Reduced dimension: {pca.n_components_}")
print(f"  - Dimensionality reduction: {(1 - pca.n_components_/len(feature_cols))*100:.1f}%")
print(f"  - Cumulative explained variance: {pca.explained_variance_ratio_.sum():.4f}")

print("\nExplained Variance per Component:")
for i, var in enumerate(pca.explained_variance_ratio_, 1):
    cumsum = pca.explained_variance_ratio_[:i].sum()
    print(f"  pca_{i}: {var:.4f} (cumulative: {cumsum:.4f})")

print("\nPCA Transformed Data Shapes:")
print(f"  - X_train_p: {X_train_p.shape}")
print(f"  - X_test_p: {X_test_p.shape}")

# ============================================================================
# 7. PCA LOADINGS - FEATURE COMPOSITION OF PRINCIPAL COMPONENTS
# ============================================================================
print("\n" + "="*80)
print("7. PCA LOADINGS - FEATURE COMPOSITION OF PRINCIPAL COMPONENTS")
print("="*80)
print("This shows which original features (excluding date) contribute most to each PCA component\n")

for comp_idx in range(min(10, pca.n_components_)):  # Show first 10 components
    comp_name = f"pca_{comp_idx+1}"
    print(f"\n--- {comp_name.upper()} (Explains {pca.explained_variance_ratio_[comp_idx]:.4f} variance) ---")
    top_10 = top_loadings(comp_name, 10)
    print(top_10.to_frame('abs_loading').to_string())

# ============================================================================
# 8. STANDARDIZATION (PRE-PCA) DETAILS
# ============================================================================
print("\n" + "="*80)
print("8. STANDARDIZATION (PRE-PCA) DETAILS")
print("="*80)
print("StandardScaler applied before PCA (numeric features only; date excluded):")
print("  - Method: z-score normalization (mean=0, std=1)")
print("  - Fitted on: Training data only")
print("  - Applied to: Both training and test data")
print("\nScaler statistics (from training data):")
scaler_means = pd.Series(scaler.mean_, index=feature_cols)
scaler_stds = pd.Series(scaler.scale_, index=feature_cols)
scaler_stats = pd.DataFrame({'mean': scaler_means, 'std': scaler_stds})
print(scaler_stats.to_string())

# ============================================================================
# 9. BASELINE MODEL PERFORMANCE (FROM PHASE 1)
# ============================================================================
print("\n" + "="*80)
print("9. BASELINE MODEL PERFORMANCE (FROM PHASE 1)")
print("="*80)
metrics_path = PROC_DIR / "phase1_metrics.csv"
if metrics_path.exists():
    metrics_df = pd.read_csv(metrics_path)
    print("Baseline model results to compare against:")
    print(metrics_df.to_string(index=False))
else:
    print("Phase 1 metrics file not found")

# ============================================================================
# 10. DATA QUALITY SUMMARY
# ============================================================================
print("\n" + "="*80)
print("10. DATA QUALITY SUMMARY")
print("="*80)
print(f"Missing values in original df: {df.isna().sum().sum():,}")
print(f"Missing values after dropna: {model_df.isna().sum().sum()}")
print(f"Rows dropped due to NaN: {len(df) - len(model_df):,}")
print(f"Percentage of data retained: {len(model_df)/len(df)*100:.2f}%")

print("\n" + "="*80)
print("END OF DATASET & PCA INFORMATION")
print("="*80)
# Out:
# ================================================================================
# COMPLETE DATASET AND PCA INFORMATION
# ================================================================================
#
# ================================================================================
# 1. DATASET OVERVIEW
# ================================================================================
# Dataset: AAPL Stock Price Prediction
# Target Variable: target_logret_1d
# Index Column: date (preserved as a datetime column, used for temporal ordering)
# Total Rows (after dropna): 3,097
# Total Original Features (excluding date and target): 283
#
# Train/Test Split (80/20 temporal split):
#   - Training rows: 2,477 (80.0%)
#   - Test rows: 620 (20.0%)
#   - Train date range: 2013-04-02 to 2023-06-01
#   - Test date range: 2023-06-02 to 2026-01-22
#
# ================================================================================
# 2. INDEX (DATE) DETAILS
# ================================================================================
# Date column retained (not dropped) to preserve temporal index.
#   - Unique dates: 3,097
#   - Min date: 2013-04-02
#   - Max date: 2026-01-22
#   - Dominant gap between rows (days): 1.0
#
# ================================================================================
# 3. FEATURE INFORMATION
# ================================================================================
# Total number of numeric features (excludes date and target): 283
#
# All columns including index and target (285 columns):
#     1. date (index)
#     2. Open
#     3. High
#     4. Low
#     5. Close
#     6. Adj Close
#     7. Volume
#     8. adj_close
#     9. logret_1d
#    10. ret_1d
#    11. hl_range
#    12. oc_change
#    13. ret_mean_5
#    14. ret_vol_5
#    15. ret_mean_10
#    16. ret_vol_10
#    17. ret_mean_20
#    18. ret_vol_20
#    19. ret_mean_60
#    20. ret_vol_60
#    21. sma_5
#    22. sma_10
#    23. sma_20
#    24. sma_60
#    25. sma_spread_5
#    26. sma_spread_20
#    27. sma_spread_60
#    28. ema_12
#    29. ema_26
#    30. macd
#    31. macd_signal
#    32. macd_hist
#    33. rsi_14
#    34. bb_mid_20
#    35. bb_std_20
#    36. bb_upper_20
#    37. bb_lower_20
#    38. bb_width_20
#    39. vol_change
#    40. vol_z_20
#    41. obv
#    42. dow
#    43. month
#    44. is_month_end
#    45. logret_1d_lag1
#    46. logret_1d_lag2
#    47. logret_1d_lag3
#    48. logret_1d_lag4
#    49. logret_1d_lag5
#    50. logret_1d_lag6
#    51. logret_1d_lag7
#    52. logret_1d_lag8
#    53. logret_1d_lag9
#    54. logret_1d_lag10
#    55. logret_1d_lag11
#    56. logret_1d_lag12
#    57. logret_1d_lag13
#    58. logret_1d_lag14
#    59. logret_1d_lag15
#    60. logret_1d_lag16
#    61. logret_1d_lag17
#    62. logret_1d_lag18
#    63. logret_1d_lag19
#    64. logret_1d_lag20
#    65. logret_1d_lag21
#    66. logret_1d_lag22
#    67. logret_1d_lag23
#    68. logret_1d_lag24
#    69. logret_1d_lag25
#    70. logret_1d_lag26
#    71. logret_1d_lag27
#    72. logret_1d_lag28
#    73. logret_1d_lag29
#    74. logret_1d_lag30
#    75. logret_1d_lag31
#    76. logret_1d_lag32
#    77. logret_1d_lag33
#    78. logret_1d_lag34
#    79. logret_1d_lag35
#    80. logret_1d_lag36
#    81. logret_1d_lag37
#    82. logret_1d_lag38
#    83. logret_1d_lag39
#    84. logret_1d_lag40
#    85. logret_1d_lag41
#    86. logret_1d_lag42
#    87. logret_1d_lag43
#    88. logret_1d_lag44
#    89. logret_1d_lag45
#    90. logret_1d_lag46
#    91. logret_1d_lag47
#    92. logret_1d_lag48
#    93. logret_1d_lag49
#    94. logret_1d_lag50
#    95. logret_1d_lag51
#    96. logret_1d_lag52
#    97. logret_1d_lag53
#    98. logret_1d_lag54
#    99. logret_1d_lag55
#   100. logret_1d_lag56
#   101. logret_1d_lag57
#   102. logret_1d_lag58
#   103. logret_1d_lag59
#   104. logret_1d_lag60
#   105. AAPL_logret_lag1
#   106. CL=F_logret_lag1
#   107. GC=F_logret_lag1
#   108. QQQ_logret_lag1
#   109. SPY_logret_lag1
#   110. UUP_logret_lag1
#   111. XLK_logret_lag1
#   112. ^TNX_logret_lag1
#   113. ^VIX_logret_lag1
#   114. AAPL_logret_lag2
#   115. CL=F_logret_lag2
#   116. GC=F_logret_lag2
#   117. QQQ_logret_lag2
#   118. SPY_logret_lag2
#   119. UUP_logret_lag2
#   120. XLK_logret_lag2
#   121. ^TNX_logret_lag2
#   122. ^VIX_logret_lag2
#   123. AAPL_logret_lag3
#   124. CL=F_logret_lag3
#   125. GC=F_logret_lag3
#   126. QQQ_logret_lag3
#   127. SPY_logret_lag3
#   128. UUP_logret_lag3
#   129. XLK_logret_lag3
#   130. ^TNX_logret_lag3
#   131. ^VIX_logret_lag3
#   132. AAPL_logret_lag4
#   133. CL=F_logret_lag4
#   134. GC=F_logret_lag4
#   135. QQQ_logret_lag4
#   136. SPY_logret_lag4
#   137. UUP_logret_lag4
#   138. XLK_logret_lag4
#   139. ^TNX_logret_lag4
#   140. ^VIX_logret_lag4
#   141. AAPL_logret_lag5
#   142. CL=F_logret_lag5
#   143. GC=F_logret_lag5
#   144. QQQ_logret_lag5
#   145. SPY_logret_lag5
#   146. UUP_logret_lag5
#   147. XLK_logret_lag5
#   148. ^TNX_logret_lag5
#   149. ^VIX_logret_lag5
#   150. AAPL_logret_lag6
#   151. CL=F_logret_lag6
#   152. GC=F_logret_lag6
#   153. QQQ_logret_lag6
#   154. SPY_logret_lag6
#   155. UUP_logret_lag6
#   156. XLK_logret_lag6
#   157. ^TNX_logret_lag6
#   158. ^VIX_logret_lag6
#   159. AAPL_logret_lag7
#   160. CL=F_logret_lag7
#   161. GC=F_logret_lag7
#   162. QQQ_logret_lag7
#   163. SPY_logret_lag7
#   164. UUP_logret_lag7
#   165. XLK_logret_lag7
#   166. ^TNX_logret_lag7
#   167. ^VIX_logret_lag7
#   168. AAPL_logret_lag8
#   169. CL=F_logret_lag8
#   170. GC=F_logret_lag8
#   171. QQQ_logret_lag8
#   172. SPY_logret_lag8
#   173. UUP_logret_lag8
#   174. XLK_logret_lag8
#   175. ^TNX_logret_lag8
#   176. ^VIX_logret_lag8
#   177. AAPL_logret_lag9
#   178. CL=F_logret_lag9
#   179. GC=F_logret_lag9
#   180. QQQ_logret_lag9
#   181. SPY_logret_lag9
#   182. UUP_logret_lag9
#   183. XLK_logret_lag9
#   184. ^TNX_logret_lag9
#   185. ^VIX_logret_lag9
#   186. AAPL_logret_lag10
#   187. CL=F_logret_lag10
#   188. GC=F_logret_lag10
#   189. QQQ_logret_lag10
#   190. SPY_logret_lag10
#   191. UUP_logret_lag10
#   192. XLK_logret_lag10
#   193. ^TNX_logret_lag10
#   194. ^VIX_logret_lag10
#   195. AAPL_logret_lag11
#   196. CL=F_logret_lag11
#   197. GC=F_logret_lag11
#   198. QQQ_logret_lag11
#   199. SPY_logret_lag11
#   200. UUP_logret_lag11
#   201. XLK_logret_lag11
#   202. ^TNX_logret_lag11
#   203. ^VIX_logret_lag11
#   204. AAPL_logret_lag12
#   205. CL=F_logret_lag12
#   206. GC=F_logret_lag12
#   207. QQQ_logret_lag12
#   208. SPY_logret_lag12
#   209. UUP_logret_lag12
#   210. XLK_logret_lag12
#   211. ^TNX_logret_lag12
#   212. ^VIX_logret_lag12
#   213. AAPL_logret_lag13
#   214. CL=F_logret_lag13
#   215. GC=F_logret_lag13
#   216. QQQ_logret_lag13
#   217. SPY_logret_lag13
#   218. UUP_logret_lag13
#   219. XLK_logret_lag13
#   220. ^TNX_logret_lag13
#   221. ^VIX_logret_lag13
#   222. AAPL_logret_lag14
#   223. CL=F_logret_lag14
#   224. GC=F_logret_lag14
#   225. QQQ_logret_lag14
#   226. SPY_logret_lag14
#   227. UUP_logret_lag14
#   228. XLK_logret_lag14
#   229. ^TNX_logret_lag14
#   230. ^VIX_logret_lag14
#   231. AAPL_logret_lag15
#   232. CL=F_logret_lag15
#   233. GC=F_logret_lag15
#   234. QQQ_logret_lag15
#   235. SPY_logret_lag15
#   236. UUP_logret_lag15
#   237. XLK_logret_lag15
#   238. ^TNX_logret_lag15
#   239. ^VIX_logret_lag15
#   240. AAPL_logret_lag16
#   241. CL=F_logret_lag16
#   242. GC=F_logret_lag16
#   243. QQQ_logret_lag16
#   244. SPY_logret_lag16
#   245. UUP_logret_lag16
#   246. XLK_logret_lag16
#   247. ^TNX_logret_lag16
#   248. ^VIX_logret_lag16
#   249. AAPL_logret_lag17
#   250. CL=F_logret_lag17
#   251. GC=F_logret_lag17
#   252. QQQ_logret_lag17
#   253. SPY_logret_lag17
#   254. UUP_logret_lag17
#   255. XLK_logret_lag17
#   256. ^TNX_logret_lag17
#   257. ^VIX_logret_lag17
#   258. AAPL_logret_lag18
#   259. CL=F_logret_lag18
#   260. GC=F_logret_lag18
#   261. QQQ_logret_lag18
#   262. SPY_logret_lag18
#   263. UUP_logret_lag18
#   264. XLK_logret_lag18
#   265. ^TNX_logret_lag18
#   266. ^VIX_logret_lag18
#   267. AAPL_logret_lag19
#   268. CL=F_logret_lag19
#   269. GC=F_logret_lag19
#   270. QQQ_logret_lag19
#   271. SPY_logret_lag19
#   272. UUP_logret_lag19
#   273. XLK_logret_lag19
#   274. ^TNX_logret_lag19
#   275. ^VIX_logret_lag19
#   276. AAPL_logret_lag20
#   277. CL=F_logret_lag20
#   278. GC=F_logret_lag20
#   279. QQQ_logret_lag20
#   280. SPY_logret_lag20
#   281. UUP_logret_lag20
#   282. XLK_logret_lag20
#   283. ^TNX_logret_lag20
#   284. ^VIX_logret_lag20
#   285. target_logret_1d
#
# Feature names only (283 features):
#     1. Open
#     2. High
#     3. Low
#     4. Close
#     5. Adj Close
#     6. Volume
#     7. adj_close
#     8. logret_1d
#     9. ret_1d
#    10. hl_range
#    11. oc_change
#    12. ret_mean_5
#    13. ret_vol_5
#    14. ret_mean_10
#    15. ret_vol_10
#    16. ret_mean_20
#    17. ret_vol_20
#    18. ret_mean_60
#    19. ret_vol_60
#    20. sma_5
#    21. sma_10
#    22. sma_20
#    23. sma_60
#    24. sma_spread_5
#    25. sma_spread_20
#    26. sma_spread_60
#    27. ema_12
#    28. ema_26
#    29. macd
#    30. macd_signal
#    31. macd_hist
#    32. rsi_14
#    33. bb_mid_20
#    34. bb_std_20
#    35. bb_upper_20
#    36. bb_lower_20
#    37. bb_width_20
#    38. vol_change
#    39. vol_z_20
#    40. obv
#    41. dow
#    42. month
#    43. is_month_end
#    44. logret_1d_lag1
#    45. logret_1d_lag2
#    46. logret_1d_lag3
#    47. logret_1d_lag4
#    48. logret_1d_lag5
#    49. logret_1d_lag6
#    50. logret_1d_lag7
#    51. logret_1d_lag8
#    52. logret_1d_lag9
#    53. logret_1d_lag10
#    54. logret_1d_lag11
#    55. logret_1d_lag12
#    56. logret_1d_lag13
#    57. logret_1d_lag14
#    58. logret_1d_lag15
#    59. logret_1d_lag16
#    60. logret_1d_lag17
#    61. logret_1d_lag18
#    62. logret_1d_lag19
#    63. logret_1d_lag20
#    64. logret_1d_lag21
#    65. logret_1d_lag22
#    66. logret_1d_lag23
#    67. logret_1d_lag24
#    68. logret_1d_lag25
#    69. logret_1d_lag26
#    70. logret_1d_lag27
#    71. logret_1d_lag28
#    72. logret_1d_lag29
#    73. logret_1d_lag30
#    74. logret_1d_lag31
#    75. logret_1d_lag32
#    76. logret_1d_lag33
#    77. logret_1d_lag34
#    78. logret_1d_lag35
#    79. logret_1d_lag36
#    80. logret_1d_lag37
#    81. logret_1d_lag38
#    82. logret_1d_lag39
#    83. logret_1d_lag40
#    84. logret_1d_lag41
#    85. logret_1d_lag42
#    86. logret_1d_lag43
#    87. logret_1d_lag44
#    88. logret_1d_lag45
#    89. logret_1d_lag46
#    90. logret_1d_lag47
#    91. logret_1d_lag48
#    92. logret_1d_lag49
#    93. logret_1d_lag50
#    94. logret_1d_lag51
#    95. logret_1d_lag52
#    96. logret_1d_lag53
#    97. logret_1d_lag54
#    98. logret_1d_lag55
#    99. logret_1d_lag56
#   100. logret_1d_lag57
#   101. logret_1d_lag58
#   102. logret_1d_lag59
#   103. logret_1d_lag60
#   104. AAPL_logret_lag1
#   105. CL=F_logret_lag1
#   106. GC=F_logret_lag1
#   107. QQQ_logret_lag1
#   108. SPY_logret_lag1
#   109. UUP_logret_lag1
#   110. XLK_logret_lag1
#   111. ^TNX_logret_lag1
#   112. ^VIX_logret_lag1
#   113. AAPL_logret_lag2
#   114. CL=F_logret_lag2
#   115. GC=F_logret_lag2
#   116. QQQ_logret_lag2
#   117. SPY_logret_lag2
#   118. UUP_logret_lag2
#   119. XLK_logret_lag2
#   120. ^TNX_logret_lag2
#   121. ^VIX_logret_lag2
#   122. AAPL_logret_lag3
#   123. CL=F_logret_lag3
#   124. GC=F_logret_lag3
#   125. QQQ_logret_lag3
#   126. SPY_logret_lag3
#   127. UUP_logret_lag3
#   128. XLK_logret_lag3
#   129. ^TNX_logret_lag3
#   130. ^VIX_logret_lag3
#   131. AAPL_logret_lag4
#   132. CL=F_logret_lag4
#   133. GC=F_logret_lag4
#   134. QQQ_logret_lag4
#   135. SPY_logret_lag4
#   136. UUP_logret_lag4
#   137. XLK_logret_lag4
#   138. ^TNX_logret_lag4
#   139. ^VIX_logret_lag4
#   140. AAPL_logret_lag5
#   141. CL=F_logret_lag5
#   142. GC=F_logret_lag5
#   143. QQQ_logret_lag5
#   144. SPY_logret_lag5
#   145. UUP_logret_lag5
#   146. XLK_logret_lag5
#   147. ^TNX_logret_lag5
#   148. ^VIX_logret_lag5
#   149. AAPL_logret_lag6
#   150. CL=F_logret_lag6
#   151. GC=F_logret_lag6
#   152. QQQ_logret_lag6
#   153. SPY_logret_lag6
#   154. UUP_logret_lag6
#   155. XLK_logret_lag6
#   156. ^TNX_logret_lag6
#   157. ^VIX_logret_lag6
#   158. AAPL_logret_lag7
#   159. CL=F_logret_lag7
#   160. GC=F_logret_lag7
#   161. QQQ_logret_lag7
#   162. SPY_logret_lag7
#   163. UUP_logret_lag7
#   164. XLK_logret_lag7
#   165. ^TNX_logret_lag7
#   166. ^VIX_logret_lag7
#   167. AAPL_logret_lag8
#   168. CL=F_logret_lag8
#   169. GC=F_logret_lag8
#   170. QQQ_logret_lag8
#   171. SPY_logret_lag8
#   172. UUP_logret_lag8
#   173. XLK_logret_lag8
#   174. ^TNX_logret_lag8
#   175. ^VIX_logret_lag8
#   176. AAPL_logret_lag9
#   177. CL=F_logret_lag9
#   178. GC=F_logret_lag9
#   179. QQQ_logret_lag9
#   180. SPY_logret_lag9
#   181. UUP_logret_lag9
#   182. XLK_logret_lag9
#   183. ^TNX_logret_lag9
#   184. ^VIX_logret_lag9
#   185. AAPL_logret_lag10
#   186. CL=F_logret_lag10
#   187. GC=F_logret_lag10
#   188. QQQ_logret_lag10
#   189. SPY_logret_lag10
#   190. UUP_logret_lag10
#   191. XLK_logret_lag10
#   192. ^TNX_logret_lag10
#   193. ^VIX_logret_lag10
#   194. AAPL_logret_lag11
#   195. CL=F_logret_lag11
#   196. GC=F_logret_lag11
#   197. QQQ_logret_lag11
#   198. SPY_logret_lag11
#   199. UUP_logret_lag11
#   200. XLK_logret_lag11
#   201. ^TNX_logret_lag11
#   202. ^VIX_logret_lag11
#   203. AAPL_logret_lag12
#   204. CL=F_logret_lag12
#   205. GC=F_logret_lag12
#   206. QQQ_logret_lag12
#   207. SPY_logret_lag12
#   208. UUP_logret_lag12
#   209. XLK_logret_lag12
#   210. ^TNX_logret_lag12
#   211. ^VIX_logret_lag12
#   212. AAPL_logret_lag13
#   213. CL=F_logret_lag13
#   214. GC=F_logret_lag13
#   215. QQQ_logret_lag13
#   216. SPY_logret_lag13
#   217. UUP_logret_lag13
#   218. XLK_logret_lag13
#   219. ^TNX_logret_lag13
#   220. ^VIX_logret_lag13
#   221. AAPL_logret_lag14
#   222. CL=F_logret_lag14
#   223. GC=F_logret_lag14
#   224. QQQ_logret_lag14
#   225. SPY_logret_lag14
#   226. UUP_logret_lag14
#   227. XLK_logret_lag14
#   228. ^TNX_logret_lag14
#   229. ^VIX_logret_lag14
#   230. AAPL_logret_lag15
#   231. CL=F_logret_lag15
#   232. GC=F_logret_lag15
#   233. QQQ_logret_lag15
#   234. SPY_logret_lag15
#   235. UUP_logret_lag15
#   236. XLK_logret_lag15
#   237. ^TNX_logret_lag15
#   238. ^VIX_logret_lag15
#   239. AAPL_logret_lag16
#   240. CL=F_logret_lag16
#   241. GC=F_logret_lag16
#   242. QQQ_logret_lag16
#   243. SPY_logret_lag16
#   244. UUP_logret_lag16
#   245. XLK_logret_lag16
#   246. ^TNX_logret_lag16
#   247. ^VIX_logret_lag16
#   248. AAPL_logret_lag17
#   249. CL=F_logret_lag17
#   250. GC=F_logret_lag17
#   251. QQQ_logret_lag17
#   252. SPY_logret_lag17
#   253. UUP_logret_lag17
#   254. XLK_logret_lag17
#   255. ^TNX_logret_lag17
#   256. ^VIX_logret_lag17
#   257. AAPL_logret_lag18
#   258. CL=F_logret_lag18
#   259. GC=F_logret_lag18
#   260. QQQ_logret_lag18
#   261. SPY_logret_lag18
#   262. UUP_logret_lag18
#   263. XLK_logret_lag18
#   264. ^TNX_logret_lag18
#   265. ^VIX_logret_lag18
#   266. AAPL_logret_lag19
#   267. CL=F_logret_lag19
#   268. GC=F_logret_lag19
#   269. QQQ_logret_lag19
#   270. SPY_logret_lag19
#   271. UUP_logret_lag19
#   272. XLK_logret_lag19
#   273. ^TNX_logret_lag19
#   274. ^VIX_logret_lag19
#   275. AAPL_logret_lag20
#   276. CL=F_logret_lag20
#   277. GC=F_logret_lag20
#   278. QQQ_logret_lag20
#   279. SPY_logret_lag20
#   280. UUP_logret_lag20
#   281. XLK_logret_lag20
#   282. ^TNX_logret_lag20
#   283. ^VIX_logret_lag20
#
# --- Training Data Feature Statistics (numeric features only) ---
# Feature value ranges (min, max, mean, std):
#                             min           max          mean           std
# Open               1.385607e+01  1.826300e+02  6.809084e+01  5.171938e+01
# High               1.427143e+01  1.829400e+02  6.885811e+01  5.238383e+01
# Low                1.375357e+01  1.791200e+02  6.736262e+01  5.110277e+01
# Close              1.394750e+01  1.820100e+02  6.814431e+01  5.177825e+01
# Adj Close          1.188528e+01  1.782703e+02  6.547161e+01  5.164441e+01
# Volume             3.519590e+07  1.065523e+09  1.588156e+08  1.098297e+08
# adj_close          1.188528e+01  1.782703e+02  6.547161e+01  5.164441e+01
# logret_1d         -1.377083e-01  1.131577e-01  9.698469e-04  1.807749e-02
# ret_1d            -1.286471e-01  1.198085e-01  1.133621e-03  1.807161e-02
# hl_range           4.382079e-03  1.629170e-01  2.000296e-02  1.176613e-02
# oc_change         -7.257864e-02  8.696110e-02  6.337197e-04  1.385292e-02
# ret_mean_5        -3.606091e-02  3.501569e-02  1.141310e-03  7.549528e-03
# ret_vol_5          7.553896e-04  1.073097e-01  1.539228e-02  1.000466e-02
# ret_mean_10       -2.010518e-02  2.111422e-02  1.137375e-03  5.315972e-03
# ret_vol_10         3.595620e-03  8.005623e-02  1.599353e-02  8.677020e-03
# ret_mean_20       -1.352525e-02  1.532091e-02  1.153209e-03  3.819065e-03
# ret_vol_20         4.815353e-03  6.800421e-02  1.640103e-02  7.582765e-03
# ret_mean_60       -7.106847e-03  8.258416e-03  1.143979e-03  2.123322e-03
# ret_vol_60         6.551770e-03  4.499690e-02  1.689656e-02  5.692500e-03
# XLK_logret_lag6   0.103955
# logret_1d_lag7    0.097293
# AAPL_logret_lag7  0.097293
# SPY_logret_lag6   0.097103
# QQQ_logret_lag6   0.096027
# SPY_logret_lag8   0.090016
# QQQ_logret_lag14  0.086478
# logret_1d_lag8    0.085158
# AAPL_logret_lag8  0.085158
# SPY_logret_lag14  0.083550
# XLK_logret_lag8   0.082473
# XLK_logret_lag14  0.081106
# SPY_logret_lag5   0.080272
# logret_1d_lag6    0.079410
# AAPL_logret_lag6  0.079410
# XLK_logret_lag5   0.079401
# QQQ_logret_lag8   0.078910
# ^TNX_logret_lag8  0.073293
# QQQ_logret_lag5   0.073257
# ret_1d            0.067552
# logret_1d         0.067485
# ^VIX_logret_lag7  0.066059
#
# Top 25 Features by Mutual Information with Target:
#                   mutual_info
# ret_vol_10           0.058560
# hl_range             0.055978
# ret_1d               0.055113
# logret_1d            0.053923
# sma_5                0.051344
# macd                 0.047551
# High                 0.038625
# rsi_14               0.035834
# ^VIX_logret_lag4     0.034488
# Close                0.032971
# ret_mean_20          0.032621
# SPY_logret_lag11     0.032286
# XLK_logret_lag19     0.032057
# sma_spread_60        0.031476
# ret_vol_60           0.031423
# GC=F_logret_lag2     0.030983
# sma_60               0.030969
# bb_upper_20          0.030885
# logret_1d_lag31      0.030805
# adj_close            0.030020
# bb_std_20            0.030018
# Adj Close            0.029977
# Open                 0.029907
# ret_mean_5           0.029627
# sma_spread_5         0.029449
#
# ================================================================================
# 6. PCA TRANSFORMATION DETAILS
# ================================================================================
# PCA Configuration:
#   - Variance retention threshold: 80%
#   - SVD solver: full
#   - Number of components selected: 91
#   - Original feature dimension: 283 (date excluded)
#   - Reduced dimension: 91
#   - Dimensionality reduction: 67.8%
#   - Cumulative explained variance: 0.8023
#
# Explained Variance per Component:
#   pca_1: 0.0605 (cumulative: 0.0605)
#   pca_2: 0.0385 (cumulative: 0.0990)
#   pca_3: 0.0355 (cumulative: 0.1345)
#   pca_4: 0.0334 (cumulative: 0.1679)
#   pca_5: 0.0211 (cumulative: 0.1889)
#   pca_6: 0.0207 (cumulative: 0.2097)
#   pca_7: 0.0204 (cumulative: 0.2301)
#   pca_8: 0.0191 (cumulative: 0.2492)
#   pca_9: 0.0186 (cumulative: 0.2678)
#   pca_10: 0.0178 (cumulative: 0.2856)
#   pca_11: 0.0174 (cumulative: 0.3030)
#   pca_12: 0.0173 (cumulative: 0.3203)
#   pca_13: 0.0172 (cumulative: 0.3375)
#   pca_14: 0.0171 (cumulative: 0.3546)
#   pca_15: 0.0169 (cumulative: 0.3715)
#   pca_16: 0.0163 (cumulative: 0.3878)
#   pca_17: 0.0162 (cumulative: 0.4040)
#   pca_18: 0.0158 (cumulative: 0.4198)
#   pca_19: 0.0154 (cumulative: 0.4352)
#   pca_20: 0.0152 (cumulative: 0.4503)
#   pca_21: 0.0147 (cumulative: 0.4651)
#   pca_22: 0.0120 (cumulative: 0.4771)
#   pca_23: 0.0104 (cumulative: 0.4875)
#   pca_24: 0.0085 (cumulative: 0.4960)
#   pca_25: 0.0075 (cumulative: 0.5035)
#   pca_26: 0.0074 (cumulative: 0.5109)
#   pca_27: 0.0070 (cumulative: 0.5179)
#   pca_28: 0.0069 (cumulative: 0.5248)
#   pca_29: 0.0068 (cumulative: 0.5316)
#   pca_30: 0.0065 (cumulative: 0.5381)
#   pca_31: 0.0064 (cumulative: 0.5446)
#   pca_32: 0.0064 (cumulative: 0.5510)
#   pca_33: 0.0063 (cumulative: 0.5573)
#   pca_34: 0.0062 (cumulative: 0.5635)
#   pca_35: 0.0062 (cumulative: 0.5696)
#   pca_36: 0.0061 (cumulative: 0.5757)
#   pca_37: 0.0060 (cumulative: 0.5817)
#   pca_38: 0.0058 (cumulative: 0.5875)
#   pca_39: 0.0058 (cumulative: 0.5934)
#   pca_40: 0.0058 (cumulative: 0.5992)
#   pca_41: 0.0057 (cumulative: 0.6049)
#   pca_42: 0.0055 (cumulative: 0.6104)
#   pca_43: 0.0054 (cumulative: 0.6158)
#   pca_44: 0.0054 (cumulative: 0.6212)
#   pca_45: 0.0050 (cumulative: 0.6262)
#   pca_46: 0.0048 (cumulative: 0.6310)
#   pca_47: 0.0048 (cumulative: 0.6358)
#   pca_48: 0.0048 (cumulative: 0.6406)
#   pca_49: 0.0047 (cumulative: 0.6453)
#   pca_50: 0.0045 (cumulative: 0.6498)
#   pca_51: 0.0044 (cumulative: 0.6542)
#   pca_52: 0.0044 (cumulative: 0.6586)
#   pca_53: 0.0043 (cumulative: 0.6630)
#   pca_54: 0.0043 (cumulative: 0.6672)
#   pca_55: 0.0042 (cumulative: 0.6714)
#   pca_56: 0.0041 (cumulative: 0.6755)
#   pca_57: 0.0041 (cumulative: 0.6797)
#   pca_58: 0.0041 (cumulative: 0.6838)
#   pca_59: 0.0041 (cumulative: 0.6878)
#   pca_60: 0.0040 (cumulative: 0.6919)
#   pca_61: 0.0040 (cumulative: 0.6959)
#   pca_62: 0.0039 (cumulative: 0.6998)
#   pca_63: 0.0039 (cumulative: 0.7037)
#   pca_64: 0.0039 (cumulative: 0.7076)
#   pca_65: 0.0039 (cumulative: 0.7115)
#   pca_66: 0.0038 (cumulative: 0.7153)
#   pca_67: 0.0038 (cumulative: 0.7192)
#   pca_68: 0.0038 (cumulative: 0.7230)
#   pca_69: 0.0038 (cumulative: 0.7267)
#   pca_70: 0.0037 (cumulative: 0.7305)
#   pca_71: 0.0037 (cumulative: 0.7341)
#   pca_72: 0.0036 (cumulative: 0.7377)
#   pca_73: 0.0036 (cumulative: 0.7413)
#   pca_74: 0.0036 (cumulative: 0.7449)
#   pca_75: 0.0036 (cumulative: 0.7485)
#   pca_76: 0.0035 (cumulative: 0.7520)
#   pca_77: 0.0035 (cumulative: 0.7555)
#   pca_78: 0.0035 (cumulative: 0.7590)
#   pca_79: 0.0035 (cumulative: 0.7625)
#   pca_80: 0.0035 (cumulative: 0.7660)
#   pca_81: 0.0034 (cumulative: 0.7694)
#   pca_82: 0.0034 (cumulative: 0.7728)
#   pca_83: 0.0034 (cumulative: 0.7762)
#   pca_84: 0.0034 (cumulative: 0.7795)
#   pca_85: 0.0033 (cumulative: 0.7829)
#   pca_86: 0.0033 (cumulative: 0.7862)
#   pca_87: 0.0033 (cumulative: 0.7894)
#   pca_88: 0.0033 (cumulative: 0.7927)
#   pca_89: 0.0032 (cumulative: 0.7959)
#   pca_90: 0.0032 (cumulative: 0.7991)
#   pca_91: 0.0032 (cumulative: 0.8023)
#
# PCA Transformed Data Shapes:
#   - X_train_p: (2477, 91)
#   - X_test_p: (620, 91)
#
# ================================================================================
# 7. PCA LOADINGS - FEATURE COMPOSITION OF PRINCIPAL COMPONENTS
# ================================================================================
# This shows which original features (excluding date) contribute most to each PCA component
#
#
# --- PCA_1 (Explains 0.0605 variance) ---
#              abs_loading
# bb_upper_20     0.241004
# ema_12          0.240628
# sma_10          0.240588
# ema_26          0.240551
# sma_20          0.240532
# bb_mid_20       0.240532
# sma_5           0.240531
# High            0.240523
# Open            0.240417
# adj_close       0.240411
#
# --- PCA_2 (Explains 0.0385 variance) ---
#                abs_loading
# sma_spread_20     0.274255
# ret_mean_20       0.270796
# rsi_14            0.265498
# sma_spread_60     0.261440
# ret_mean_10       0.243044
# macd              0.224651
# ret_mean_5        0.197022
# macd_signal       0.185618
# ret_mean_60       0.183355
# sma_spread_5      0.165674
#
# --- PCA_3 (Explains 0.0355 variance) ---
#                    abs_loading
# SPY_logret_lag10      0.154230
# XLK_logret_lag10      0.152905
# QQQ_logret_lag10      0.146122
# SPY_logret_lag3       0.141638
# XLK_logret_lag3       0.139791
# SPY_logret_lag11      0.134999
# XLK_logret_lag11      0.132887
# QQQ_logret_lag3       0.131334
# AAPL_logret_lag10     0.128835
# logret_1d_lag10       0.128835
#
# --- PCA_4 (Explains 0.0334 variance) ---
#                   abs_loading
# SPY_logret_lag6      0.150429
# XLK_logret_lag6      0.149163
# SPY_logret_lag7      0.145117
# XLK_logret_lag7      0.142771
# SPY_logret_lag14     0.142253
# SPY_logret_lag13     0.141805
# QQQ_logret_lag6      0.141671
# XLK_logret_lag14     0.141206
# XLK_logret_lag13     0.139719
# QQQ_logret_lag7      0.134569
#
# --- PCA_5 (Explains 0.0211 variance) ---
#                    abs_loading
# SPY_logret_lag17      0.134991
# XLK_logret_lag17      0.134706
# QQQ_logret_lag17      0.132094
# ret_mean_5            0.130248
# XLK_logret_lag5       0.129872
# XLK_logret_lag14      0.129747
# QQQ_logret_lag14      0.128309
# logret_1d_lag17       0.127939
# AAPL_logret_lag17     0.127939
# logret_1d_lag14       0.127114
#
# --- PCA_6 (Explains 0.0207 variance) ---
#                    abs_loading
# XLK_logret_lag15      0.162168
# QQQ_logret_lag15      0.159522
# SPY_logret_lag15      0.156477
# XLK_logret_lag12      0.153794
# logret_1d_lag15       0.153114
# AAPL_logret_lag15     0.153114
# QQQ_logret_lag12      0.150488
# logret_1d_lag12       0.147223
# AAPL_logret_lag12     0.147223
# SPY_logret_lag12      0.143578
#
# --- PCA_7 (Explains 0.0204 variance) ---
#                    abs_loading
# ret_mean_5            0.203317
# sma_spread_5          0.202168
# ret_vol_20            0.171086
# macd_signal           0.160047
# QQQ_logret_lag16      0.159432
# XLK_logret_lag16      0.158417
# macd_hist             0.157613
# SPY_logret_lag16      0.155538
# logret_1d_lag16       0.147680
# AAPL_logret_lag16     0.147680
#
# --- PCA_8 (Explains 0.0191 variance) ---
#                    abs_loading
# XLK_logret_lag2       0.205134
# QQQ_logret_lag2       0.202867
# SPY_logret_lag2       0.201283
# logret_1d_lag2        0.194185
# AAPL_logret_lag2      0.194185
# XLK_logret_lag19      0.180440
# SPY_logret_lag19      0.178513
# QQQ_logret_lag19      0.176336
# ^VIX_logret_lag2      0.170426
# AAPL_logret_lag19     0.158079
#
# --- PCA_9 (Explains 0.0186 variance) ---
#                    abs_loading
# XLK_logret_lag20      0.209684
# QQQ_logret_lag20      0.206517
# SPY_logret_lag20      0.200094
# XLK_logret_lag3       0.193645
# AAPL_logret_lag3      0.189859
# logret_1d_lag3        0.189859
# QQQ_logret_lag3       0.189320
# AAPL_logret_lag20     0.187045
# logret_1d_lag20       0.187045
# SPY_logret_lag3       0.180651
#
# --- PCA_10 (Explains 0.0178 variance) ---
#                    abs_loading
# logret_1d_lag4        0.196791
# AAPL_logret_lag4      0.196791
# QQQ_logret_lag4       0.191890
# XLK_logret_lag4       0.190957
# SPY_logret_lag4       0.177797
# QQQ_logret_lag19      0.164012
# XLK_logret_lag19      0.163054
# SPY_logret_lag19      0.160100
# logret_1d_lag19       0.146388
# AAPL_logret_lag19     0.146388
#
# ================================================================================
# 8. STANDARDIZATION (PRE-PCA) DETAILS
# ================================================================================
# StandardScaler applied before PCA (numeric features only; date excluded):
#   - Method: z-score normalization (mean=0, std=1)
#   - Fitted on: Training data only
#   - Applied to: Both training and test data
#
# Scaler statistics (from training data):
#                            mean           std
# Open               6.809084e+01  5.170894e+01
# High               6.885811e+01  5.237326e+01
# Low                6.736262e+01  5.109245e+01
# Close              6.814431e+01  5.176780e+01
# Adj Close          6.547161e+01  5.163398e+01
# Volume             1.588156e+08  1.098076e+08
# adj_close          6.547161e+01  5.163398e+01
# logret_1d          9.698469e-04  1.807384e-02
# ret_1d             1.133621e-03  1.806797e-02
# hl_range           2.000296e-02  1.176375e-02
# oc_change          6.337197e-04  1.385013e-02
# ret_mean_5         1.141310e-03  7.548004e-03
# ret_vol_5          1.539228e-02  1.000264e-02
# ret_mean_10        1.137375e-03  5.314899e-03
# ret_vol_10         1.599353e-02  8.675268e-03
# ret_mean_20        1.153209e-03  3.818294e-03
# ret_vol_20         1.640103e-02  7.581234e-03
# ret_mean_60        1.143979e-03  2.122894e-03
# ret_vol_60         1.689656e-02  5.691351e-03
# sma_5              6.534831e+01  5.154002e+01
# sma_10             6.519618e+01  5.143651e+01
# sma_20             6.489301e+01  5.123213e+01
# sma_60             6.367408e+01  5.047122e+01
# sma_spread_5       2.000840e-03  1.884146e-02
# sma_spread_20      9.761910e-03  4.243310e-02
# sma_spread_60      3.087428e-02  7.606635e-02
# ema_12             6.513621e+01  5.137595e+01
# ^VIX_logret_lag10  5.416630e-05  7.782749e-02
# AAPL_logret_lag11  9.797292e-04  1.800682e-02
# CL=F_logret_lag11 -2.225436e-05  2.610347e-02
# GC=F_logret_lag11  1.181030e-04  9.881074e-03
# QQQ_logret_lag11   6.123359e-04  1.329241e-02
# SPY_logret_lag11   4.215754e-04  1.086113e-02
# UUP_logret_lag11   9.230694e-05  4.555974e-03
# XLK_logret_lag11   6.554598e-04  1.385644e-02
# ^TNX_logret_lag11  4.130724e-05  3.059400e-02
# ^VIX_logret_lag11 -1.713315e-05  7.773565e-02
# AAPL_logret_lag12  1.009772e-03  1.801919e-02
# CL=F_logret_lag12 -7.803750e-05  2.572226e-02
# GC=F_logret_lag12  1.210013e-04  9.863249e-03
# QQQ_logret_lag12   6.224798e-04  1.329330e-02
# SPY_logret_lag12   4.243882e-04  1.085420e-02
# UUP_logret_lag12   8.860558e-05  4.556612e-03
# XLK_logret_lag12   6.677780e-04  1.385593e-02
# ^TNX_logret_lag12  3.676366e-05  3.059100e-02
# ^VIX_logret_lag12 -1.002243e-04  7.774102e-02
# AAPL_logret_lag13  1.036974e-03  1.798307e-02
# CL=F_logret_lag13 -9.345156e-05  2.575379e-02
# GC=F_logret_lag13  1.149114e-04  9.862667e-03
# QQQ_logret_lag13   6.359680e-04  1.327910e-02
# SPY_logret_lag13   4.379255e-04  1.083095e-02
# UUP_logret_lag13   9.192540e-05  4.555580e-03
# XLK_logret_lag13   6.864581e-04  1.383831e-02
# ^TNX_logret_lag13  8.082312e-05  3.053279e-02
# ^VIX_logret_lag13 -1.517873e-04  7.777020e-02
# AAPL_logret_lag14  1.024150e-03  1.800238e-02
# CL=F_logret_lag14 -3.874943e-05  2.612712e-02
# GC=F_logret_lag14  1.120436e-04  9.858343e-03
# QQQ_logret_lag14   6.170433e-04  1.330577e-02
# SPY_logret_lag14   4.197930e-04  1.085380e-02
# UUP_logret_lag14   9.175055e-05  4.556530e-03
# XLK_logret_lag14   6.687279e-04  1.385898e-02
# ^TNX_logret_lag14  4.816866e-05  3.051759e-02
# ^VIX_logret_lag14  2.548603e-05  7.779159e-02
# AAPL_logret_lag15  1.019336e-03  1.801201e-02
# CL=F_logret_lag15  8.328744e-05  2.640238e-02
# GC=F_logret_lag15  1.142978e-04  9.860324e-03
# QQQ_logret_lag15   6.053277e-04  1.330559e-02
# SPY_logret_lag15   4.167547e-04  1.084791e-02
# UUP_logret_lag15   8.568499e-05  4.556460e-03
# XLK_logret_lag15   6.627242e-04  1.385888e-02
# ^TNX_logret_lag15  1.136890e-04  3.044311e-02
# ^VIX_logret_lag15 -5.073269e-05  7.779339e-02
# AAPL_logret_lag16  1.050779e-03  1.801022e-02
# CL=F_logret_lag16  1.086258e-04  2.640263e-02
# GC=F_logret_lag16  1.196039e-04  9.855276e-03
# QQQ_logret_lag16   6.224134e-04  1.330113e-02
# SPY_logret_lag16   4.374260e-04  1.083844e-02
# UUP_logret_lag16   9.117734e-05  4.555856e-03
# XLK_logret_lag16   6.850506e-04  1.383901e-02
# ^TNX_logret_lag16  1.309810e-04  3.043979e-02
# ^VIX_logret_lag16 -1.911498e-04  7.791211e-02
# AAPL_logret_lag17  1.029573e-03  1.798890e-02
# CL=F_logret_lag17  3.521797e-05  2.695207e-02
# GC=F_logret_lag17  1.102519e-04  9.853446e-03
# QQQ_logret_lag17   5.896648e-04  1.328792e-02
# SPY_logret_lag17   4.038644e-04  1.081690e-02
# UUP_logret_lag17   9.253871e-05  4.542655e-03
# XLK_logret_lag17   6.511660e-04  1.381405e-02
# ^TNX_logret_lag17  1.993844e-04  3.049304e-02
# ^VIX_logret_lag17  1.023962e-04  7.942374e-02
# AAPL_logret_lag18  1.010250e-03  1.801035e-02
# CL=F_logret_lag18 -2.802058e-08  2.694148e-02
# GC=F_logret_lag18  1.063536e-04  9.848376e-03
# QQQ_logret_lag18   5.821625e-04  1.329308e-02
# SPY_logret_lag18   3.896529e-04  1.082372e-02
# UUP_logret_lag18   1.018247e-04  4.542955e-03
# XLK_logret_lag18   6.413549e-04  1.382998e-02
# ^TNX_logret_lag18  2.012203e-04  3.049701e-02
# ^VIX_logret_lag18  2.066903e-04  7.958649e-02
# AAPL_logret_lag19  9.514776e-04  1.788584e-02
# CL=F_logret_lag19  6.484072e-05  2.716198e-02
# GC=F_logret_lag19  8.837479e-05  9.774678e-03
# QQQ_logret_lag19   5.336021e-04  1.320267e-02
# SPY_logret_lag19   3.430143e-04  1.067785e-02
# UUP_logret_lag19   1.065718e-04  4.537967e-03
# XLK_logret_lag19   5.871578e-04  1.368621e-02
# ^TNX_logret_lag19  1.635207e-04  3.046148e-02
# ^VIX_logret_lag19  3.420688e-04  7.948880e-02
# AAPL_logret_lag20  9.709226e-04  1.788970e-02
# CL=F_logret_lag20  2.060518e-04  2.791442e-02
# GC=F_logret_lag20  7.238579e-05  9.728236e-03
# QQQ_logret_lag20   5.624628e-04  1.321588e-02
# SPY_logret_lag20   3.799892e-04  1.066932e-02
# UUP_logret_lag20   1.099361e-04  4.536911e-03
# XLK_logret_lag20   6.245667e-04  1.370665e-02
# ^TNX_logret_lag20  2.928567e-04  3.021311e-02
# ^VIX_logret_lag20  1.100145e-04  7.944771e-02
#
# ================================================================================
# 9. BASELINE MODEL PERFORMANCE (FROM PHASE 1)
# ================================================================================
# Baseline model results to compare against:
#             model      MAE     RMSE        R2      MDA
#             Naive 0.010954 0.016341 -0.001397 0.456452
#             ARIMA 0.010946 0.016338 -0.001065 0.520968
#            ARIMAX 0.011260 0.016579 -0.030851 0.522581
#           XGBoost 0.011975 0.017424 -0.138567 0.496774
#         Ridge_PCA 0.011675 0.016945 -0.076779 0.493548
#       XGBoost_PCA 0.011075 0.016321  0.000952 0.529032
# XGBoost_PCA_Tuned 0.011075 0.016321  0.000952 0.529032
#
# ================================================================================
# 10. DATA QUALITY SUMMARY
# ================================================================================
# Missing values in original df: 5,215
# Missing values after dropna: 0
# Rows dropped due to NaN: 188
# Percentage of data retained: 94.28%
#
# ================================================================================
# END OF DATASET & PCA INFORMATION
# ================================================================================
