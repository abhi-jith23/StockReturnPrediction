# %% [markdown]
# # LSTM + GRU Hybrid Model for Stock Prediction

# %% [markdown]
# ## Imports and Config

# %%
#cell 1: imports + seeds + device
import os
import random
from pathlib import Path

import numpy as np
import pandas as pd

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

set_seed(42)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("device:", device)
# Out:
# device: cuda

# %% [markdown]
# ## Loading the Data

# %%
#cell 2: project paths + load panel + filter AAPL
cwd = Path.cwd().resolve()
project_root = None
for p in [cwd] + list(cwd.parents):
    if (p / "data").exists():
        project_root = p
        break
if project_root is None:
    raise RuntimeError("Project root not found: missing /data folder")

DATA_DIR = project_root / "data"
PROC_DIR = DATA_DIR / "processed"

panel_path = PROC_DIR / "modeling_panel_targets.parquet"
print("project_root:", project_root)
print("panel_path:", panel_path)

df = pd.read_parquet(panel_path)
df["date"] = pd.to_datetime(df["date"])

df = df.sort_values(["ticker", "date"]).reset_index(drop=True)
df = df[df["ticker"] == "AAPL"].copy()
df = df.sort_values("date").reset_index(drop=True)

# --- 20-day forward log return target (create if missing) ---
HORIZON = 20
target_20 = f"target_logret_{HORIZON}d"
price_col = "Adj Close" if "Adj Close" in df.columns else "Close"

if target_20 not in df.columns:
    df[target_20] = np.log(df[price_col].shift(-HORIZON) / df[price_col])

print("Using target column:", target_20, "| price_col:", price_col)

df.columns = (
    pd.Index(df.columns)
    .str.replace("_logret_laglogret_lag", "_logret_lag", regex=False)
)

cols_to_drop = [c for c in df.columns if c.startswith(("MSFT_", "GOOG_", "AMZN_"))]
df = df.drop(columns=cols_to_drop)

print("AAPL df shape:", df.shape)
display(df.head(3))
# Out:
# project_root: /media/workhorse/Windows/MyWorkPlace/Projects/StockPredictor
# panel_path: /media/workhorse/Windows/MyWorkPlace/Projects/StockPredictor/data/processed/modeling_panel_targets.parquet
# Using target column: target_logret_20d | price_col: Adj Close
# AAPL df shape: (3285, 287)
#         date ticker       Open       High        Low      Close  Adj Close  \
# 0 2013-01-02   AAPL  19.779285  19.821428  19.343929  19.608213  16.612209
# 1 2013-01-03   AAPL  19.567142  19.631071  19.321428  19.360714  16.402523
# 2 2013-01-04   AAPL  19.177500  19.236786  18.779642  18.821428  15.945646
#
#         Volume  adj_close  logret_1d  ...  AAPL_logret_lag20  \
# 0  560518000.0  16.612209        NaN  ...                NaN
# 1  352965200.0  16.402523  -0.012703  ...                NaN
# 2  594333600.0  15.945646  -0.028249  ...                NaN
#
#    CL=F_logret_lag20  GC=F_logret_lag20  QQQ_logret_lag20  SPY_logret_lag20  \
# 0                NaN                NaN               NaN               NaN
# 1                NaN                NaN               NaN               NaN
# 2                NaN                NaN               NaN               NaN
#
#    UUP_logret_lag20  XLK_logret_lag20  ^TNX_logret_lag20  ^VIX_logret_lag20  \
# 0               NaN               NaN                NaN                NaN
# 1               NaN               NaN                NaN                NaN
# 2               NaN               NaN                NaN                NaN
#
#    target_logret_20d
# 0          -0.186779
# 1          -0.178190
# 2          -0.175167
#
# [3 rows x 287 columns]

# %%
#print all the columns in the dataframe
print("Columns in the dataframe:", df.columns.tolist())
# Out:
# Columns in the dataframe: ['date', 'ticker', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'adj_close', 'logret_1d', 'ret_1d', 'target_logret_1d', 'hl_range', 'oc_change', 'ret_mean_5', 'ret_vol_5', 'ret_mean_10', 'ret_vol_10', 'ret_mean_20', 'ret_vol_20', 'ret_mean_60', 'ret_vol_60', 'sma_5', 'sma_10', 'sma_20', 'sma_60', 'sma_spread_5', 'sma_spread_20', 'sma_spread_60', 'ema_12', 'ema_26', 'macd', 'macd_signal', 'macd_hist', 'rsi_14', 'bb_mid_20', 'bb_std_20', 'bb_upper_20', 'bb_lower_20', 'bb_width_20', 'vol_change', 'vol_z_20', 'obv', 'dow', 'month', 'is_month_end', 'logret_1d_lag1', 'logret_1d_lag2', 'logret_1d_lag3', 'logret_1d_lag4', 'logret_1d_lag5', 'logret_1d_lag6', 'logret_1d_lag7', 'logret_1d_lag8', 'logret_1d_lag9', 'logret_1d_lag10', 'logret_1d_lag11', 'logret_1d_lag12', 'logret_1d_lag13', 'logret_1d_lag14', 'logret_1d_lag15', 'logret_1d_lag16', 'logret_1d_lag17', 'logret_1d_lag18', 'logret_1d_lag19', 'logret_1d_lag20', 'logret_1d_lag21', 'logret_1d_lag22', 'logret_1d_lag23', 'logret_1d_lag24', 'logret_1d_lag25', 'logret_1d_lag26', 'logret_1d_lag27', 'logret_1d_lag28', 'logret_1d_lag29', 'logret_1d_lag30', 'logret_1d_lag31', 'logret_1d_lag32', 'logret_1d_lag33', 'logret_1d_lag34', 'logret_1d_lag35', 'logret_1d_lag36', 'logret_1d_lag37', 'logret_1d_lag38', 'logret_1d_lag39', 'logret_1d_lag40', 'logret_1d_lag41', 'logret_1d_lag42', 'logret_1d_lag43', 'logret_1d_lag44', 'logret_1d_lag45', 'logret_1d_lag46', 'logret_1d_lag47', 'logret_1d_lag48', 'logret_1d_lag49', 'logret_1d_lag50', 'logret_1d_lag51', 'logret_1d_lag52', 'logret_1d_lag53', 'logret_1d_lag54', 'logret_1d_lag55', 'logret_1d_lag56', 'logret_1d_lag57', 'logret_1d_lag58', 'logret_1d_lag59', 'logret_1d_lag60', 'AAPL_logret_lag1', 'CL=F_logret_lag1', 'GC=F_logret_lag1', 'QQQ_logret_lag1', 'SPY_logret_lag1', 'UUP_logret_lag1', 'XLK_logret_lag1', '^TNX_logret_lag1', '^VIX_logret_lag1', 'AAPL_logret_lag2', 'CL=F_logret_lag2', 'GC=F_logret_lag2', 'QQQ_logret_lag2', 'SPY_logret_lag2', 'UUP_logret_lag2', 'XLK_logret_lag2', '^TNX_logret_lag2', '^VIX_logret_lag2', 'AAPL_logret_lag3', 'CL=F_logret_lag3', 'GC=F_logret_lag3', 'QQQ_logret_lag3', 'SPY_logret_lag3', 'UUP_logret_lag3', 'XLK_logret_lag3', '^TNX_logret_lag3', '^VIX_logret_lag3', 'AAPL_logret_lag4', 'CL=F_logret_lag4', 'GC=F_logret_lag4', 'QQQ_logret_lag4', 'SPY_logret_lag4', 'UUP_logret_lag4', 'XLK_logret_lag4', '^TNX_logret_lag4', '^VIX_logret_lag4', 'AAPL_logret_lag5', 'CL=F_logret_lag5', 'GC=F_logret_lag5', 'QQQ_logret_lag5', 'SPY_logret_lag5', 'UUP_logret_lag5', 'XLK_logret_lag5', '^TNX_logret_lag5', '^VIX_logret_lag5', 'AAPL_logret_lag6', 'CL=F_logret_lag6', 'GC=F_logret_lag6', 'QQQ_logret_lag6', 'SPY_logret_lag6', 'UUP_logret_lag6', 'XLK_logret_lag6', '^TNX_logret_lag6', '^VIX_logret_lag6', 'AAPL_logret_lag7', 'CL=F_logret_lag7', 'GC=F_logret_lag7', 'QQQ_logret_lag7', 'SPY_logret_lag7', 'UUP_logret_lag7', 'XLK_logret_lag7', '^TNX_logret_lag7', '^VIX_logret_lag7', 'AAPL_logret_lag8', 'CL=F_logret_lag8', 'GC=F_logret_lag8', 'QQQ_logret_lag8', 'SPY_logret_lag8', 'UUP_logret_lag8', 'XLK_logret_lag8', '^TNX_logret_lag8', '^VIX_logret_lag8', 'AAPL_logret_lag9', 'CL=F_logret_lag9', 'GC=F_logret_lag9', 'QQQ_logret_lag9', 'SPY_logret_lag9', 'UUP_logret_lag9', 'XLK_logret_lag9', '^TNX_logret_lag9', '^VIX_logret_lag9', 'AAPL_logret_lag10', 'CL=F_logret_lag10', 'GC=F_logret_lag10', 'QQQ_logret_lag10', 'SPY_logret_lag10', 'UUP_logret_lag10', 'XLK_logret_lag10', '^TNX_logret_lag10', '^VIX_logret_lag10', 'AAPL_logret_lag11', 'CL=F_logret_lag11', 'GC=F_logret_lag11', 'QQQ_logret_lag11', 'SPY_logret_lag11', 'UUP_logret_lag11', 'XLK_logret_lag11', '^TNX_logret_lag11', '^VIX_logret_lag11', 'AAPL_logret_lag12', 'CL=F_logret_lag12', 'GC=F_logret_lag12', 'QQQ_logret_lag12', 'SPY_logret_lag12', 'UUP_logret_lag12', 'XLK_logret_lag12', '^TNX_logret_lag12', '^VIX_logret_lag12', 'AAPL_logret_lag13', 'CL=F_logret_lag13', 'GC=F_logret_lag13', 'QQQ_logret_lag13', 'SPY_logret_lag13', 'UUP_logret_lag13', 'XLK_logret_lag13', ' ...

# %% [markdown]
# ## Data Split

# %%
#cell 3: define X/y and time split (OLD VERSION)
'''TARGET = "target_logret_20d"

drop_cols = {
    "date", "ticker",
    TARGET,
}

num_cols = df.select_dtypes(include=[np.number]).columns.tolist()
feature_cols = [c for c in num_cols if c not in drop_cols]

model_df = df[["date", TARGET] + feature_cols].dropna().reset_index(drop=True)'''

#cell 3: define X/y and time split (drop ALL other target_* columns to avoid leakage)
TARGET = "target_logret_20d"

drop_cols = {"date", "ticker", TARGET}

num_cols = df.select_dtypes(include=[np.number]).columns.tolist()

# Drop any other target-like columns (future info leakage)
leak_cols = [c for c in num_cols if c.startswith("target_") and c != TARGET]
drop_cols = drop_cols.union(leak_cols)

feature_cols = [c for c in num_cols if c not in drop_cols]

print("Dropped potential leakage columns:", len(leak_cols))
if len(leak_cols) > 0:
    print("Examples:", leak_cols[:10])

model_df = df[["date", TARGET] + feature_cols].dropna().reset_index(drop=True)


n = len(model_df)
split_idx = int(n * 0.80)

train_df = model_df.iloc[:split_idx].copy()
test_df  = model_df.iloc[split_idx:].copy()

X_train = train_df[feature_cols].copy()
y_train = train_df[TARGET].copy()

X_test  = test_df[feature_cols].copy()
y_test  = test_df[TARGET].copy()

print("model_df shape:", model_df.shape)
print("train rows:", len(train_df), "test rows:", len(test_df))
print("train date range:", train_df["date"].min(), "to", train_df["date"].max())
print("test  date range:", test_df["date"].min(), "to", test_df["date"].max())
# Out:
# Dropped potential leakage columns: 1
# Examples: ['target_logret_1d']
# model_df shape: (3078, 285)
# train rows: 2462 test rows: 616
# train date range: 2013-04-02 00:00:00 to 2023-05-10 00:00:00
# test  date range: 2023-05-11 00:00:00 to 2025-12-23 00:00:00

# %%
print("Any target_* columns still in features?",
      any(c.startswith("target_") for c in feature_cols))
# Out:
# Any target_* columns still in features? False

# %% [markdown]
# ## Scaling and PCA

# %%
#cell 4: StandardScaler + PCA(80% variance)
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

scaler = StandardScaler()
X_train_s = scaler.fit_transform(X_train.values)
X_test_s  = scaler.transform(X_test.values)

pca = PCA(n_components=0.80, svd_solver="full")
X_train_p = pca.fit_transform(X_train_s)
X_test_p  = pca.transform(X_test_s)

pca_columns = [f"pca_{i+1}" for i in range(pca.n_components_)]

print("PCA components for 80% variance:", pca.n_components_)
print("Explained variance ratio sum:", float(pca.explained_variance_ratio_.sum()))
print("X_train_p:", X_train_p.shape, "X_test_p:", X_test_p.shape)
# Out:
# PCA components for 80% variance: 91
# Explained variance ratio sum: 0.8024344539261916
# X_train_p: (2462, 91) X_test_p: (616, 91)

# %% [markdown]
# ## Sliding Window Sequences

# %%
#cell 5: build sliding-window sequences (lookback=60) with test continuity
LOOKBACK = 60

def make_sequences(X_2d, y_1d, lookback):
    Xs, ys = [], []
    for t in range(lookback, len(X_2d)):
        Xs.append(X_2d[t - lookback:t])
        ys.append(y_1d[t])
    return np.array(Xs, dtype=np.float32), np.array(ys, dtype=np.float32)

Xtr_seq, ytr_seq = make_sequences(X_train_p, y_train.values, LOOKBACK)

#test continuity: prepend last LOOKBACK rows of train to test features, then keep test targets only
X_test_full = np.vstack([X_train_p[-LOOKBACK:], X_test_p])
y_test_full = np.concatenate([y_train.values[-LOOKBACK:], y_test.values])

Xte_seq_all, yte_seq_all = make_sequences(X_test_full, y_test_full, LOOKBACK)

#only keep sequences whose target is in the real test period
Xte_seq = Xte_seq_all
yte_seq = yte_seq_all

print("train sequences:", Xtr_seq.shape, ytr_seq.shape)
print("test  sequences:", Xte_seq.shape, yte_seq.shape)
# Out:
# train sequences: (2402, 60, 91) (2402,)
# test  sequences: (616, 60, 91) (616,)

# %% [markdown]
# ## Temporal Train/Val Split

# %%
#cell 6: temporal train/val split on sequences (train-only)
n_train_seq = len(Xtr_seq)
val_start = int(n_train_seq * 0.90)

Xtr2, ytr2 = Xtr_seq[:val_start], ytr_seq[:val_start]
Xva,  yva  = Xtr_seq[val_start:], ytr_seq[val_start:]

print("train2:", Xtr2.shape, ytr2.shape)
print("val   :", Xva.shape, yva.shape)
# Out:
# train2: (2161, 60, 91) (2161,)
# val   : (241, 60, 91) (241,)

# %%
# DIAG: exact target-date ranges for sequences and splits
train_target_dates = train_df["date"].values[LOOKBACK:]   # one per ytr_seq
val_start = int(len(train_target_dates) * 0.90)

print("Train target dates total:", len(train_target_dates), "== ytr_seq:", len(ytr_seq))
print("Train2 targets:", val_start, "| Val targets:", len(train_target_dates) - val_start)

print("TRAIN2 date range:",
      pd.to_datetime(train_target_dates[0]),
      "to",
      pd.to_datetime(train_target_dates[val_start-1]))

print("VAL date range:",
      pd.to_datetime(train_target_dates[val_start]),
      "to",
      pd.to_datetime(train_target_dates[-1]))

print("TEST date range:",
      pd.to_datetime(test_df["date"].values[0]),
      "to",
      pd.to_datetime(test_df["date"].values[-1]))
# Out:
# Train target dates total: 2402 == ytr_seq: 2402
# Train2 targets: 2161 | Val targets: 241
# TRAIN2 date range: 2013-06-26 00:00:00 to 2022-05-24 00:00:00
# VAL date range: 2022-05-25 00:00:00 to 2023-05-10 00:00:00
# TEST date range: 2023-05-11 00:00:00 to 2025-12-23 00:00:00

# %% [markdown]
# ## Loading the LSTM + GRU Model

# %%
#cell 7: torch datasets + loaders
class SeqDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.from_numpy(X)
        self.y = torch.from_numpy(y)

    def __len__(self):
        return self.X.shape[0]

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

def make_loader(X, y, batch_size, shuffle):
    ds = SeqDataset(X, y)
    return DataLoader(ds, batch_size=batch_size, shuffle=shuffle, drop_last=False)

print("ready")
# Out:
# ready

# %%
#cell 8: LSTM -> GRU -> Dense -> Dense -> Output model
class LSTMGRU(nn.Module):
    def __init__(self, n_features, hidden_lstm=128, hidden_gru=128, dense1=64, dense2=32, dropout=0.0):
        super().__init__()
        self.lstm = nn.LSTM(input_size=n_features, hidden_size=hidden_lstm, batch_first=True)
        self.gru  = nn.GRU(input_size=hidden_lstm, hidden_size=hidden_gru, batch_first=True)
        self.fc1  = nn.Linear(hidden_gru, dense1)
        self.fc2  = nn.Linear(dense1, dense2)
        self.out  = nn.Linear(dense2, 1)
        self.act  = nn.ReLU()
        self.drop = nn.Dropout(dropout)

    def forward(self, x):
        x, _ = self.lstm(x)
        x, _ = self.gru(x)
        x = x[:, -1, :]
        x = self.drop(self.act(self.fc1(x)))
        x = self.drop(self.act(self.fc2(x)))
        y = self.out(x).squeeze(-1)
        return y

print("ready")
# Out:
# ready

# %%
#cell 9: training utilities

from sklearn.metrics import r2_score

def rmse_np(y_true, y_pred):
    y_true = np.asarray(y_true)
    y_pred = np.asarray(y_pred)
    return float(np.sqrt(np.mean((y_true - y_pred) ** 2)))

def r2_np(y_true, y_pred):
    y_true = np.asarray(y_true)
    y_pred = np.asarray(y_pred)
    return float(r2_score(y_true, y_pred))


@torch.no_grad()
def predict_loader(model, loader):
    model.eval()
    preds = []
    ys = []
    for xb, yb in loader:
        xb = xb.to(device)
        yb = yb.to(device)
        p = model(xb)
        preds.append(p.detach().cpu().numpy())
        ys.append(yb.detach().cpu().numpy())
    return np.concatenate(ys), np.concatenate(preds)

def train_one_trial(model, train_loader, val_loader, lr, weight_decay, grad_clip, max_epochs, patience):
    crit = nn.MSELoss()
    opt = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)

    best_val_rmse = float("inf")
    best_state = None
    no_improve = 0

    for epoch in range(max_epochs):
        model.train()
        for xb, yb in train_loader:
            xb = xb.to(device)
            yb = yb.to(device)

            opt.zero_grad(set_to_none=True)
            pred = model(xb)
            loss = crit(pred, yb)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=grad_clip)
            opt.step()

        yv_true, yv_pred = predict_loader(model, val_loader)
        val_rmse = rmse_np(yv_true, yv_pred)

        if val_rmse < best_val_rmse:
            best_val_rmse = val_rmse
            best_state = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}
            no_improve = 0
        else:
            no_improve += 1
            if no_improve >= patience:
                break

    model.load_state_dict(best_state)
    return float(best_val_rmse)

# %% [markdown]
# ## Training the Model

# %%
#cell 10: Grid Search (single validation split + resume + append-to-CSV per run)
import itertools
import time
import json

N_FEATURES = Xtr2.shape[-1]

# ---- Grid (edit ONLY these lists to widen/narrow the grid) ----
GRID = {
    "hidden_lstm":  [64, 128, 256],
    "hidden_gru":   [64, 128, 256],
    "dense1":       [32, 64, 128],
    "dense2":       [16, 32, 64],
    "dropout":      [0.0, 0.2],
    "lr":           [5e-4, 1e-3],
    "weight_decay": [1e-6, 1e-4],
    "batch_size":   [64, 128],
    "grad_clip":    [1.0],
}

MAX_EPOCHS = 50
PATIENCE = 7
BASE_SEED = 42

runs_path = PROC_DIR / "phase2_gridsearch_runs_rmse.csv"

param_keys = list(GRID.keys())
all_params = [
    dict(zip(param_keys, vals))
    for vals in itertools.product(*[GRID[k] for k in param_keys])
]
print("total grid combinations:", len(all_params))
print("runs_path:", runs_path)

def config_to_id(p):
    # stable + comparable across sessions for resume/skip
    return json.dumps(p, sort_keys=True)

def append_row_csv(path, row, columns):
    dfrow = pd.DataFrame([row], columns=columns)
    header = not path.exists()
    dfrow.to_csv(path, mode="a", header=header, index=False)

# Resume support: skip already completed configs (by config_id)
done_ids = set()
next_run_id = 1
if runs_path.exists():
    prev = pd.read_csv(runs_path)
    if len(prev) > 0:
        if "config_id" in prev.columns:
            done_ids = set(prev["config_id"].astype(str).tolist())
        next_run_id = int(prev["run_id"].max()) + 1

columns = [
    "run_id", "seed", "status",
    "val_rmse", "val_r2",
    "train_seconds", "config_id", "error_msg",
    *param_keys
]

best_val = float("inf")

best_params = None
best_run_id = None

print("starting grid search...")
for p in all_params:
    cfg_id = config_to_id(p)
    if cfg_id in done_ids:
        continue

    run_id = next_run_id
    next_run_id += 1

    # per-run seeding -> reproducible per configuration
    seed = BASE_SEED + run_id
    set_seed(seed)

    train_loader = make_loader(Xtr2, ytr2, batch_size=int(p["batch_size"]), shuffle=True)
    val_loader   = make_loader(Xva,  yva,  batch_size=int(p["batch_size"]), shuffle=False)

    model = LSTMGRU(
        n_features=N_FEATURES,
        hidden_lstm=int(p["hidden_lstm"]),
        hidden_gru=int(p["hidden_gru"]),
        dense1=int(p["dense1"]),
        dense2=int(p["dense2"]),
        dropout=float(p["dropout"]),
    ).to(device)

    t0 = time.time()
    status = "ok"
    err_msg = ""

    try:
        val_rmse = train_one_trial(
            model=model,
            train_loader=train_loader,
            val_loader=val_loader,
            lr=float(p["lr"]),
            weight_decay=float(p["weight_decay"]),
            grad_clip=float(p["grad_clip"]),
            max_epochs=MAX_EPOCHS,
            patience=PATIENCE
        )

        # model is now at best-val-RMSE state; compute val_r2 for logging
        yv_true, yv_pred = predict_loader(model, val_loader)
        val_r2 = r2_np(yv_true, yv_pred)


    except Exception as e:
        val_rmse = np.nan
        val_r2 = np.nan
        status = f"error:{type(e).__name__}"
        err_msg = str(e)[:1500]

    train_seconds = float(time.time() - t0)

    row = {
        "run_id": run_id,
        "seed": seed,
        "status": status,
        "val_rmse": float(val_rmse) if np.isfinite(val_rmse) else np.nan,
        "val_r2": float(val_r2) if np.isfinite(val_r2) else np.nan,
        "train_seconds": train_seconds,
        "config_id": cfg_id,
        "error_msg": err_msg,
        **p
    }

    # SAVE IMMEDIATELY after each run
    append_row_csv(runs_path, row, columns)

    print(f"[run {run_id}] status={status} val_rmse={row['val_rmse']:.6f} val_r2={row['val_r2']:.6f} params={p}")

    if status == "ok" and np.isfinite(val_rmse) and val_rmse < best_val:
        best_val = float(val_rmse)
        best_params = dict(p)
        best_run_id = run_id

    # cleanup between runs (helps GPU memory)
    del model
    if torch.cuda.is_available():
        torch.cuda.empty_cache()

# Report best-so-far (also works if you stopped and resumed later)
if runs_path.exists():
    runs = pd.read_csv(runs_path)
    runs_ok = runs[runs["status"].astype(str) == "ok"].copy()
    runs_ok = runs_ok.dropna(subset=["val_rmse"])
    runs_ok = runs_ok.sort_values("val_rmse", ascending=True)


    if len(runs_ok) > 0:
        top = runs_ok.iloc[0]
        best_run_id = int(top["run_id"])
        best_val = float(top["val_rmse"])
        best_params = {k: top[k] for k in param_keys}

        # cast types cleanly
        for k in ["hidden_lstm","hidden_gru","dense1","dense2","batch_size"]:
            best_params[k] = int(best_params[k])
        for k in ["dropout","lr","weight_decay","grad_clip"]:
            best_params[k] = float(best_params[k])

        print("\nBEST (from CSV):")
        print("best_run_id:", best_run_id)
        print("best val_rmse:", best_val)
        print("best val_r2:", float(top["val_r2"]))

        print("best params:", best_params)
    else:
        print("\nNo successful runs yet (check errors in the CSV).")
# Out:
# total grid combinations: 1296
# runs_path: /media/workhorse/Windows/MyWorkPlace/Projects/StockPredictor/data/processed/phase2_gridsearch_runs_rmse.csv
# starting grid search...
# [run 1] status=ok val_rmse=0.081895 val_r2=0.002711 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 32, 'dense2': 16, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 2] status=ok val_rmse=0.084255 val_r2=-0.055607 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 32, 'dense2': 16, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 3] status=ok val_rmse=0.081871 val_r2=0.003293 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 32, 'dense2': 16, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 4] status=ok val_rmse=0.083988 val_r2=-0.048926 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 32, 'dense2': 16, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 5] status=ok val_rmse=0.087026 val_r2=-0.126184 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 32, 'dense2': 16, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 6] status=ok val_rmse=0.082923 val_r2=-0.022499 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 32, 'dense2': 16, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 7] status=ok val_rmse=0.083794 val_r2=-0.044077 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 32, 'dense2': 16, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 8] status=ok val_rmse=0.086132 val_r2=-0.103162 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 32, 'dense2': 16, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 9] status=ok val_rmse=0.081214 val_r2=0.019227 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 32, 'dense2': 16, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 10] status=ok val_rmse=0.081995 val_r2=0.000278 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 32, 'dense2': 16, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 11] status=ok val_rmse=0.089509 val_r2=-0.191360 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 32, 'dense2': 16, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 12] status=ok val_rmse=0.081773 val_r2=0.005682 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 32, 'dense2': 16, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 13] status=ok val_rmse=0.082630 val_r2=-0.015267 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 32, 'dense2': 16, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 14] status=ok val_rmse=0.082087 val_r2=-0.001968 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 32, 'dense2': 16, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 15] status=ok val_rmse=0.081833 val_r2=0.004206 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 32, 'dense2': 16, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 16] status=ok val_rmse=0.083525 val_r2=-0.037384 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 32, 'dense2': 16, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 17] status=ok val_rmse=0.082362 val_r2=-0.008714 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 32, 'dense2': 32, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 18] status=ok val_rmse=0.084210 val_r2=-0.054482 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 32, 'dense2': 32, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 19] status=ok val_rmse=0.081757 val_r2=0.006056 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 32, 'dense2': 32, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 20] status=ok val_rmse=0.083546 val_r2=-0.037921 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 32, 'dense2': 32, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 21] status=ok val_rmse=0.085247 val_r2=-0.080596 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 32, 'dense2': 32, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 22] status=ok val_rmse=0.084171 val_r2=-0.053493 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 32, 'dense2': 32, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 23] status=ok val_rmse=0.083610 val_r2=-0.039510 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 32, 'dense2': 32, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 24] status=ok val_rmse=0.082796 val_r2=-0.019364 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 32, 'dense2': 32, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 25] status=ok val_rmse=0.084889 val_r2=-0.071561 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 32, 'dense2': 32, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 26] status=ok val_rmse=0.082968 val_r2=-0.023591 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 32, 'dense2': 32, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 27] status=ok val_rmse=0.081332 val_r2=0.016366 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 32, 'dense2': 32, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 28] status=ok val_rmse=0.081550 val_r2=0.011097 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 32, 'dense2': 32, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 29] status=ok val_rmse=0.083200 val_r2=-0.029325 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 32, 'dense2': 32, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 30] status=ok val_rmse=0.083722 val_r2=-0.042284 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 32, 'dense2': 32, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 31] status=ok val_rmse=0.085764 val_r2=-0.093745 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 32, 'dense2': 32, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 32] status=ok val_rmse=0.085969 val_r2=-0.098994 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 32, 'dense2': 32, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 33] status=ok val_rmse=0.084269 val_r2=-0.055952 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 32, 'dense2': 64, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 34] status=ok val_rmse=0.084167 val_r2=-0.053400 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 32, 'dense2': 64, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 35] status=ok val_rmse=0.083748 val_r2=-0.042943 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 32, 'dense2': 64, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 36] status=ok val_rmse=0.081394 val_r2=0.014861 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 32, 'dense2': 64, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 37] status=ok val_rmse=0.084057 val_r2=-0.050646 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 32, 'dense2': 64, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 38] status=ok val_rmse=0.084252 val_r2=-0.055519 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 32, 'dense2': 64, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 39] status=ok val_rmse=0.095907 val_r2=-0.367747 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 32, 'dense2': 64, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 40] status=ok val_rmse=0.084004 val_r2=-0.049318 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 32, 'dense2': 64, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 41] status=ok val_rmse=0.080488 val_r2=0.036676 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 32, 'dense2': 64, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 42] status=ok val_rmse=0.081478 val_r2=0.012823 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 32, 'dense2': 64, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 43] status=ok val_rmse=0.083340 val_r2=-0.032789 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 32, 'dense2': 64, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 44] status=ok val_rmse=0.081721 val_r2=0.006927 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 32, 'dense2': 64, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 45] status=ok val_rmse=0.081381 val_r2=0.015190 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 32, 'dense2': 64, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 46] status=ok val_rmse=0.081980 val_r2=0.000622 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 32, 'dense2': 64, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 47] status=ok val_rmse=0.080991 val_r2=0.024588 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 32, 'dense2': 64, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 48] status=ok val_rmse=0.081423 val_r2=0.014167 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 32, 'dense2': 64, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 49] status=ok val_rmse=0.082761 val_r2=-0.018504 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 64, 'dense2': 16, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 50] status=ok val_rmse=0.084401 val_r2=-0.059253 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 64, 'dense2': 16, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 51] status=ok val_rmse=0.082417 val_r2=-0.010041 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 64, 'dense2': 16, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 52] status=ok val_rmse=0.083941 val_r2=-0.047752 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 64, 'dense2': 16, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 53] status=ok val_rmse=0.082421 val_r2=-0.010148 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 64, 'dense2': 16, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 54] status=ok val_rmse=0.082756 val_r2=-0.018376 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 64, 'dense2': 16, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 55] status=ok val_rmse=0.083325 val_r2=-0.032429 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 64, 'dense2': 16, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 56] status=ok val_rmse=0.085562 val_r2=-0.088612 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 64, 'dense2': 16, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 57] status=ok val_rmse=0.081979 val_r2=0.000668 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 64, 'dense2': 16, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 58] status=ok val_rmse=0.082683 val_r2=-0.016581 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 64, 'dense2': 16, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 59] status=ok val_rmse=0.084002 val_r2=-0.049271 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 64, 'dense2': 16, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 60] status=ok val_rmse=0.082437 val_r2=-0.010533 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 64, 'dense2': 16, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 61] status=ok val_rmse=0.082953 val_r2=-0.023234 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 64, 'dense2': 16, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 62] status=ok val_rmse=0.082033 val_r2=-0.000666 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 64, 'dense2': 16, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 63] status=ok val_rmse=0.087680 val_r2=-0.143181 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 64, 'dense2': 16, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 64] status=ok val_rmse=0.081530 val_r2=0.011572 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 64, 'dense2': 16, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 65] status=ok val_rmse=0.085503 val_r2=-0.087104 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 64, 'dense2': 32, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 66] status=ok val_rmse=0.084213 val_r2=-0.054541 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 64, 'dense2': 32, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 67] status=ok val_rmse=0.084834 val_r2=-0.070162 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 64, 'dense2': 32, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 68] status=ok val_rmse=0.080544 val_r2=0.035336 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 64, 'dense2': 32, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 69] status=ok val_rmse=0.094498 val_r2=-0.327875 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 64, 'dense2': 32, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 70] status=ok val_rmse=0.082838 val_r2=-0.020404 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 64, 'dense2': 32, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 71] status=ok val_rmse=0.082469 val_r2=-0.011325 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 64, 'dense2': 32, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 72] status=ok val_rmse=0.081030 val_r2=0.023652 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 64, 'dense2': 32, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 73] status=ok val_rmse=0.082385 val_r2=-0.009262 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 64, 'dense2': 32, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 74] status=ok val_rmse=0.081325 val_r2=0.016534 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 64, 'dense2': 32, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 75] status=ok val_rmse=0.082118 val_r2=-0.002727 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 64, 'dense2': 32, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 76] status=ok val_rmse=0.077827 val_r2=0.099318 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 64, 'dense2': 32, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 77] status=ok val_rmse=0.083157 val_r2=-0.028263 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 64, 'dense2': 32, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 78] status=ok val_rmse=0.083851 val_r2=-0.045514 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 64, 'dense2': 32, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 79] status=ok val_rmse=0.082161 val_r2=-0.003791 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 64, 'dense2': 32, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 80] status=ok val_rmse=0.082726 val_r2=-0.017641 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 64, 'dense2': 32, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 81] status=ok val_rmse=0.082939 val_r2=-0.022893 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 64, 'dense2': 64, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 82] status=ok val_rmse=0.081981 val_r2=0.000598 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 64, 'dense2': 64, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 83] status=ok val_rmse=0.081144 val_r2=0.020909 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 64, 'dense2': 64, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 84] status=ok val_rmse=0.080529 val_r2=0.035702 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 64, 'dense2': 64, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 85] status=ok val_rmse=0.084438 val_r2=-0.060185 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 64, 'dense2': 64, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 86] status=ok val_rmse=0.087969 val_r2=-0.150716 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 64, 'dense2': 64, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 87] status=ok val_rmse=0.095626 val_r2=-0.359758 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 64, 'dense2': 64, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 88] status=ok val_rmse=0.082250 val_r2=-0.005958 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 64, 'dense2': 64, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 89] status=ok val_rmse=0.082076 val_r2=-0.001717 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 64, 'dense2': 64, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 90] status=ok val_rmse=0.084067 val_r2=-0.050899 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 64, 'dense2': 64, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 91] status=ok val_rmse=0.084692 val_r2=-0.066584 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 64, 'dense2': 64, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 92] status=ok val_rmse=0.083562 val_r2=-0.038311 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 64, 'dense2': 64, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 93] status=ok val_rmse=0.081391 val_r2=0.014952 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 64, 'dense2': 64, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 94] status=ok val_rmse=0.082670 val_r2=-0.016267 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 64, 'dense2': 64, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 95] status=ok val_rmse=0.089466 val_r2=-0.190213 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 64, 'dense2': 64, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 96] status=ok val_rmse=0.081369 val_r2=0.015477 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 64, 'dense2': 64, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 97] status=ok val_rmse=0.084212 val_r2=-0.054529 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 128, 'dense2': 16, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 98] status=ok val_rmse=0.080591 val_r2=0.034210 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 128, 'dense2': 16, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 99] status=ok val_rmse=0.080757 val_r2=0.030237 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 128, 'dense2': 16, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 100] status=ok val_rmse=0.084304 val_r2=-0.056829 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 128, 'dense2': 16, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 101] status=ok val_rmse=0.087176 val_r2=-0.130064 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 128, 'dense2': 16, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 102] status=ok val_rmse=0.086417 val_r2=-0.110471 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 128, 'dense2': 16, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 103] status=ok val_rmse=0.082462 val_r2=-0.011158 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 128, 'dense2': 16, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 104] status=ok val_rmse=0.085470 val_r2=-0.086275 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 128, 'dense2': 16, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 105] status=ok val_rmse=0.081522 val_r2=0.011775 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 128, 'dense2': 16, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 106] status=ok val_rmse=0.080538 val_r2=0.035485 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 128, 'dense2': 16, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 107] status=ok val_rmse=0.082472 val_r2=-0.011404 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 128, 'dense2': 16, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 108] status=ok val_rmse=0.082929 val_r2=-0.022639 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 128, 'dense2': 16, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 109] status=ok val_rmse=0.081685 val_r2=0.007810 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 128, 'dense2': 16, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 110] status=ok val_rmse=0.081446 val_r2=0.013606 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 128, 'dense2': 16, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 111] status=ok val_rmse=0.081987 val_r2=0.000473 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 128, 'dense2': 16, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 112] status=ok val_rmse=0.083283 val_r2=-0.031400 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 128, 'dense2': 16, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 113] status=ok val_rmse=0.079947 val_r2=0.049582 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 128, 'dense2': 32, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 114] status=ok val_rmse=0.079821 val_r2=0.052589 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 128, 'dense2': 32, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 115] status=ok val_rmse=0.081993 val_r2=0.000326 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 128, 'dense2': 32, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 116] status=ok val_rmse=0.082219 val_r2=-0.005197 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 128, 'dense2': 32, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 117] status=ok val_rmse=0.084380 val_r2=-0.058733 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 128, 'dense2': 32, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 118] status=ok val_rmse=0.083500 val_r2=-0.036758 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 128, 'dense2': 32, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 119] status=ok val_rmse=0.084473 val_r2=-0.061075 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 128, 'dense2': 32, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 120] status=ok val_rmse=0.084122 val_r2=-0.052271 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 128, 'dense2': 32, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 121] status=ok val_rmse=0.080010 val_r2=0.048075 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 128, 'dense2': 32, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 122] status=ok val_rmse=0.082644 val_r2=-0.015631 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 128, 'dense2': 32, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 123] status=ok val_rmse=0.083039 val_r2=-0.025357 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 128, 'dense2': 32, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 124] status=ok val_rmse=0.081098 val_r2=0.022011 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 128, 'dense2': 32, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 125] status=ok val_rmse=0.085397 val_r2=-0.084410 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 128, 'dense2': 32, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 126] status=ok val_rmse=0.082607 val_r2=-0.014716 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 128, 'dense2': 32, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 127] status=ok val_rmse=0.080555 val_r2=0.035074 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 128, 'dense2': 32, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 128] status=ok val_rmse=0.086393 val_r2=-0.109857 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 128, 'dense2': 32, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 129] status=ok val_rmse=0.081663 val_r2=0.008337 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 128, 'dense2': 64, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 130] status=ok val_rmse=0.083091 val_r2=-0.026633 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 128, 'dense2': 64, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 131] status=ok val_rmse=0.081209 val_r2=0.019331 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 128, 'dense2': 64, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 132] status=ok val_rmse=0.082683 val_r2=-0.016581 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 128, 'dense2': 64, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 133] status=ok val_rmse=0.088806 val_r2=-0.172720 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 128, 'dense2': 64, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 134] status=ok val_rmse=0.088868 val_r2=-0.174349 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 128, 'dense2': 64, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 135] status=ok val_rmse=0.082695 val_r2=-0.016881 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 128, 'dense2': 64, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 136] status=ok val_rmse=0.080898 val_r2=0.026850 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 128, 'dense2': 64, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 137] status=ok val_rmse=0.084553 val_r2=-0.063089 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 128, 'dense2': 64, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 138] status=ok val_rmse=0.083318 val_r2=-0.032264 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 128, 'dense2': 64, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 139] status=ok val_rmse=0.082070 val_r2=-0.001568 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 128, 'dense2': 64, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 140] status=ok val_rmse=0.082644 val_r2=-0.015621 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 128, 'dense2': 64, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 141] status=ok val_rmse=0.084628 val_r2=-0.064970 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 128, 'dense2': 64, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 142] status=ok val_rmse=0.080632 val_r2=0.033217 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 128, 'dense2': 64, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 143] status=ok val_rmse=0.081821 val_r2=0.004505 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 128, 'dense2': 64, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 144] status=ok val_rmse=0.081329 val_r2=0.016442 params={'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 128, 'dense2': 64, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 145] status=ok val_rmse=0.080005 val_r2=0.048203 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 32, 'dense2': 16, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 146] status=ok val_rmse=0.081928 val_r2=0.001908 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 32, 'dense2': 16, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 147] status=ok val_rmse=0.081574 val_r2=0.010503 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 32, 'dense2': 16, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 148] status=ok val_rmse=0.080028 val_r2=0.047645 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 32, 'dense2': 16, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 149] status=ok val_rmse=0.082928 val_r2=-0.022624 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 32, 'dense2': 16, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 150] status=ok val_rmse=0.083446 val_r2=-0.035440 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 32, 'dense2': 16, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 151] status=ok val_rmse=0.081623 val_r2=0.009309 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 32, 'dense2': 16, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 152] status=ok val_rmse=0.084773 val_r2=-0.068622 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 32, 'dense2': 16, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 153] status=ok val_rmse=0.080161 val_r2=0.044479 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 32, 'dense2': 16, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 154] status=ok val_rmse=0.085686 val_r2=-0.091766 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 32, 'dense2': 16, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 155] status=ok val_rmse=0.092271 val_r2=-0.266023 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 32, 'dense2': 16, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 156] status=ok val_rmse=0.081749 val_r2=0.006266 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 32, 'dense2': 16, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 157] status=ok val_rmse=0.085815 val_r2=-0.095054 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 32, 'dense2': 16, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 158] status=ok val_rmse=0.083837 val_r2=-0.045154 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 32, 'dense2': 16, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 159] status=ok val_rmse=0.080717 val_r2=0.031184 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 32, 'dense2': 16, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 160] status=ok val_rmse=0.082729 val_r2=-0.017708 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 32, 'dense2': 16, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 161] status=ok val_rmse=0.082548 val_r2=-0.013265 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 32, 'dense2': 32, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 162] status=ok val_rmse=0.083913 val_r2=-0.047062 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 32, 'dense2': 32, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 163] status=ok val_rmse=0.083115 val_r2=-0.027220 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 32, 'dense2': 32, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 164] status=ok val_rmse=0.080344 val_r2=0.040119 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 32, 'dense2': 32, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 165] status=ok val_rmse=0.082993 val_r2=-0.024228 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 32, 'dense2': 32, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 166] status=ok val_rmse=0.080938 val_r2=0.025873 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 32, 'dense2': 32, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 167] status=ok val_rmse=0.085422 val_r2=-0.085043 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 32, 'dense2': 32, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 168] status=ok val_rmse=0.082708 val_r2=-0.017194 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 32, 'dense2': 32, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 169] status=ok val_rmse=0.078844 val_r2=0.075623 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 32, 'dense2': 32, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 170] status=ok val_rmse=0.081710 val_r2=0.007200 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 32, 'dense2': 32, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 171] status=ok val_rmse=0.083264 val_r2=-0.030925 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 32, 'dense2': 32, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 172] status=ok val_rmse=0.082521 val_r2=-0.012604 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 32, 'dense2': 32, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 173] status=ok val_rmse=0.081913 val_r2=0.002262 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 32, 'dense2': 32, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 174] status=ok val_rmse=0.081612 val_r2=0.009577 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 32, 'dense2': 32, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 175] status=ok val_rmse=0.085854 val_r2=-0.096038 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 32, 'dense2': 32, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 176] status=ok val_rmse=0.081371 val_r2=0.015413 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 32, 'dense2': 32, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 177] status=ok val_rmse=0.088395 val_r2=-0.161886 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 32, 'dense2': 64, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 178] status=ok val_rmse=0.082147 val_r2=-0.003436 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 32, 'dense2': 64, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 179] status=ok val_rmse=0.085707 val_r2=-0.092291 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 32, 'dense2': 64, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 180] status=ok val_rmse=0.080007 val_r2=0.048159 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 32, 'dense2': 64, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 181] status=ok val_rmse=0.090386 val_r2=-0.214815 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 32, 'dense2': 64, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 182] status=ok val_rmse=0.082416 val_r2=-0.010025 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 32, 'dense2': 64, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 183] status=ok val_rmse=0.082200 val_r2=-0.004730 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 32, 'dense2': 64, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 184] status=ok val_rmse=0.081870 val_r2=0.003316 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 32, 'dense2': 64, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 185] status=ok val_rmse=0.081926 val_r2=0.001937 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 32, 'dense2': 64, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 186] status=ok val_rmse=0.083797 val_r2=-0.044167 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 32, 'dense2': 64, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 187] status=ok val_rmse=0.077892 val_r2=0.097808 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 32, 'dense2': 64, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 188] status=ok val_rmse=0.083499 val_r2=-0.036736 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 32, 'dense2': 64, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 189] status=ok val_rmse=0.081197 val_r2=0.019627 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 32, 'dense2': 64, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 190] status=ok val_rmse=0.082775 val_r2=-0.018836 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 32, 'dense2': 64, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 191] status=ok val_rmse=0.080853 val_r2=0.027929 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 32, 'dense2': 64, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 192] status=ok val_rmse=0.081497 val_r2=0.012382 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 32, 'dense2': 64, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 193] status=ok val_rmse=0.082423 val_r2=-0.010190 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 64, 'dense2': 16, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 194] status=ok val_rmse=0.081314 val_r2=0.016796 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 64, 'dense2': 16, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 195] status=ok val_rmse=0.082168 val_r2=-0.003950 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 64, 'dense2': 16, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 196] status=ok val_rmse=0.080939 val_r2=0.025858 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 64, 'dense2': 16, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 197] status=ok val_rmse=0.085834 val_r2=-0.095552 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 64, 'dense2': 16, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 198] status=ok val_rmse=0.081383 val_r2=0.015126 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 64, 'dense2': 16, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 199] status=ok val_rmse=0.083889 val_r2=-0.046454 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 64, 'dense2': 16, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 200] status=ok val_rmse=0.085618 val_r2=-0.090022 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 64, 'dense2': 16, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 201] status=ok val_rmse=0.090637 val_r2=-0.221567 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 64, 'dense2': 16, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 202] status=ok val_rmse=0.082478 val_r2=-0.011538 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 64, 'dense2': 16, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 203] status=ok val_rmse=0.083359 val_r2=-0.033264 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 64, 'dense2': 16, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 204] status=ok val_rmse=0.088457 val_r2=-0.163524 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 64, 'dense2': 16, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 205] status=ok val_rmse=0.081671 val_r2=0.008143 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 64, 'dense2': 16, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 206] status=ok val_rmse=0.084623 val_r2=-0.064832 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 64, 'dense2': 16, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 207] status=ok val_rmse=0.081261 val_r2=0.018087 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 64, 'dense2': 16, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 208] status=ok val_rmse=0.083346 val_r2=-0.032937 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 64, 'dense2': 16, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 209] status=ok val_rmse=0.080552 val_r2=0.035141 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 64, 'dense2': 32, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 210] status=ok val_rmse=0.081138 val_r2=0.021060 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 64, 'dense2': 32, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 211] status=ok val_rmse=0.080861 val_r2=0.027739 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 64, 'dense2': 32, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 212] status=ok val_rmse=0.081922 val_r2=0.002045 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 64, 'dense2': 32, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 213] status=ok val_rmse=0.086402 val_r2=-0.110090 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 64, 'dense2': 32, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 214] status=ok val_rmse=0.084727 val_r2=-0.067452 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 64, 'dense2': 32, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 215] status=ok val_rmse=0.098350 val_r2=-0.438335 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 64, 'dense2': 32, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 216] status=ok val_rmse=0.083458 val_r2=-0.035736 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 64, 'dense2': 32, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 217] status=ok val_rmse=0.081079 val_r2=0.022485 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 64, 'dense2': 32, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 218] status=ok val_rmse=0.081886 val_r2=0.002916 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 64, 'dense2': 32, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 219] status=ok val_rmse=0.081167 val_r2=0.020346 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 64, 'dense2': 32, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 220] status=ok val_rmse=0.081085 val_r2=0.022328 params={'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 64, 'dense2': 32, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# ...
# [run 1226] status=ok val_rmse=0.082415 val_r2=-0.009990 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 64, 'dense2': 32, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 1227] status=ok val_rmse=0.093058 val_r2=-0.287713 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 64, 'dense2': 32, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 1228] status=ok val_rmse=0.085444 val_r2=-0.085599 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 64, 'dense2': 32, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 1229] status=ok val_rmse=0.092558 val_r2=-0.273907 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 64, 'dense2': 32, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 1230] status=ok val_rmse=0.087212 val_r2=-0.130990 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 64, 'dense2': 32, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 1231] status=ok val_rmse=0.086558 val_r2=-0.114110 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 64, 'dense2': 32, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 1232] status=ok val_rmse=0.086451 val_r2=-0.111359 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 64, 'dense2': 32, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 1233] status=ok val_rmse=0.093290 val_r2=-0.294124 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 64, 'dense2': 64, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 1234] status=ok val_rmse=0.082534 val_r2=-0.012923 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 64, 'dense2': 64, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 1235] status=ok val_rmse=0.091815 val_r2=-0.253533 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 64, 'dense2': 64, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 1236] status=ok val_rmse=0.081094 val_r2=0.022113 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 64, 'dense2': 64, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 1237] status=ok val_rmse=0.093971 val_r2=-0.313111 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 64, 'dense2': 64, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 1238] status=ok val_rmse=0.092972 val_r2=-0.285340 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 64, 'dense2': 64, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 1239] status=ok val_rmse=0.091264 val_r2=-0.238532 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 64, 'dense2': 64, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 1240] status=ok val_rmse=0.087823 val_r2=-0.146902 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 64, 'dense2': 64, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 1241] status=ok val_rmse=0.088886 val_r2=-0.174827 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 64, 'dense2': 64, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 1242] status=ok val_rmse=0.084631 val_r2=-0.065034 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 64, 'dense2': 64, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 1243] status=ok val_rmse=0.087123 val_r2=-0.128702 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 64, 'dense2': 64, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 1244] status=ok val_rmse=0.083425 val_r2=-0.034899 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 64, 'dense2': 64, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 1245] status=ok val_rmse=0.087043 val_r2=-0.126609 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 64, 'dense2': 64, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 1246] status=ok val_rmse=0.092442 val_r2=-0.270709 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 64, 'dense2': 64, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 1247] status=ok val_rmse=0.090188 val_r2=-0.209496 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 64, 'dense2': 64, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 1248] status=ok val_rmse=0.080617 val_r2=0.033579 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 64, 'dense2': 64, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 1249] status=ok val_rmse=0.084602 val_r2=-0.064312 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 128, 'dense2': 16, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 1250] status=ok val_rmse=0.085048 val_r2=-0.075565 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 128, 'dense2': 16, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 1251] status=ok val_rmse=0.097819 val_r2=-0.422828 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 128, 'dense2': 16, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 1252] status=ok val_rmse=0.085187 val_r2=-0.079081 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 128, 'dense2': 16, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 1253] status=ok val_rmse=0.091759 val_r2=-0.251997 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 128, 'dense2': 16, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 1254] status=ok val_rmse=0.090183 val_r2=-0.209356 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 128, 'dense2': 16, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 1255] status=ok val_rmse=0.089631 val_r2=-0.194617 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 128, 'dense2': 16, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 1256] status=ok val_rmse=0.097369 val_r2=-0.409775 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 128, 'dense2': 16, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 1257] status=ok val_rmse=0.088332 val_r2=-0.160236 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 128, 'dense2': 16, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 1258] status=ok val_rmse=0.092663 val_r2=-0.276794 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 128, 'dense2': 16, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 1259] status=ok val_rmse=0.082966 val_r2=-0.023548 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 128, 'dense2': 16, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 1260] status=ok val_rmse=0.090143 val_r2=-0.208300 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 128, 'dense2': 16, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 1261] status=ok val_rmse=0.085563 val_r2=-0.088633 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 128, 'dense2': 16, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 1262] status=ok val_rmse=0.085070 val_r2=-0.076123 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 128, 'dense2': 16, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 1263] status=ok val_rmse=0.089457 val_r2=-0.189977 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 128, 'dense2': 16, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 1264] status=ok val_rmse=0.085301 val_r2=-0.081968 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 128, 'dense2': 16, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 1265] status=ok val_rmse=0.091213 val_r2=-0.237153 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 128, 'dense2': 32, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 1266] status=ok val_rmse=0.086448 val_r2=-0.111270 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 128, 'dense2': 32, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 1267] status=ok val_rmse=0.086036 val_r2=-0.100695 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 128, 'dense2': 32, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 1268] status=ok val_rmse=0.088818 val_r2=-0.173049 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 128, 'dense2': 32, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 1269] status=ok val_rmse=0.094180 val_r2=-0.318936 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 128, 'dense2': 32, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 1270] status=ok val_rmse=0.090751 val_r2=-0.224650 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 128, 'dense2': 32, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 1271] status=ok val_rmse=0.084880 val_r2=-0.071322 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 128, 'dense2': 32, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 1272] status=ok val_rmse=0.090251 val_r2=-0.211199 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 128, 'dense2': 32, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 1273] status=ok val_rmse=0.090283 val_r2=-0.212061 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 128, 'dense2': 32, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 1274] status=ok val_rmse=0.085953 val_r2=-0.098589 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 128, 'dense2': 32, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 1275] status=ok val_rmse=0.085641 val_r2=-0.090612 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 128, 'dense2': 32, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 1276] status=ok val_rmse=0.083665 val_r2=-0.040870 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 128, 'dense2': 32, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 1277] status=ok val_rmse=0.083145 val_r2=-0.027982 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 128, 'dense2': 32, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 1278] status=ok val_rmse=0.090055 val_r2=-0.205948 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 128, 'dense2': 32, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 1279] status=ok val_rmse=0.089614 val_r2=-0.194153 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 128, 'dense2': 32, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 1280] status=ok val_rmse=0.080789 val_r2=0.029466 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 128, 'dense2': 32, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 1281] status=ok val_rmse=0.097675 val_r2=-0.418647 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 128, 'dense2': 64, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 1282] status=ok val_rmse=0.085340 val_r2=-0.082969 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 128, 'dense2': 64, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 1283] status=ok val_rmse=0.091693 val_r2=-0.250198 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 128, 'dense2': 64, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 1284] status=ok val_rmse=0.085123 val_r2=-0.077467 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 128, 'dense2': 64, 'dropout': 0.0, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 1285] status=ok val_rmse=0.092080 val_r2=-0.260772 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 128, 'dense2': 64, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 1286] status=ok val_rmse=0.087311 val_r2=-0.133558 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 128, 'dense2': 64, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 1287] status=ok val_rmse=0.092000 val_r2=-0.258601 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 128, 'dense2': 64, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 1288] status=ok val_rmse=0.091885 val_r2=-0.255444 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 128, 'dense2': 64, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 1289] status=ok val_rmse=0.094233 val_r2=-0.320423 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 128, 'dense2': 64, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 1290] status=ok val_rmse=0.083470 val_r2=-0.036030 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 128, 'dense2': 64, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 1291] status=ok val_rmse=0.086775 val_r2=-0.119702 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 128, 'dense2': 64, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 1292] status=ok val_rmse=0.082859 val_r2=-0.020907 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 128, 'dense2': 64, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# [run 1293] status=ok val_rmse=0.087562 val_r2=-0.140095 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 128, 'dense2': 64, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# [run 1294] status=ok val_rmse=0.092941 val_r2=-0.284474 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 128, 'dense2': 64, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# [run 1295] status=ok val_rmse=0.088674 val_r2=-0.169224 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 128, 'dense2': 64, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# [run 1296] status=ok val_rmse=0.085886 val_r2=-0.096875 params={'hidden_lstm': 256, 'hidden_gru': 256, 'dense1': 128, 'dense2': 64, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
#
# BEST (from CSV):
# best_run_id: 397
# best val_rmse: 0.0770590901374816
# best val_r2: 0.1170071959495544
# best params: {'hidden_lstm': 64, 'hidden_gru': 256, 'dense1': 128, 'dense2': 16, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}

# %%
#cell 11: retrain TOP 10 configs from CSV and print results (no saving)
grid_path = PROC_DIR / "phase2_gridsearch_runs_rmse.csv"
runs = pd.read_csv(grid_path)

runs_ok = runs[runs["status"].astype(str) == "ok"].copy()
runs_ok = runs_ok.dropna(subset=["val_rmse"]).sort_values("val_rmse", ascending=True)

TOPK = 10
top_runs = runs_ok.head(TOPK).reset_index(drop=True)

if len(top_runs) == 0:
    raise RuntimeError("No successful grid runs found. Check phase2_gridsearch_runs_rmse.csv error_msg column.")

print("Top runs loaded:", len(top_runs))
display(top_runs[["run_id","seed","val_rmse","val_r2","hidden_lstm","hidden_gru","dense1","dense2","dropout","lr","weight_decay","batch_size","grad_clip"]])

# Use SAME split as grid search (this matches your Cell 6 logic)
batch_size_default = int(top_runs.loc[0, "batch_size"])

n_train_seq = len(Xtr_seq)
val_start = int(n_train_seq * 0.90)
XtrF, ytrF = Xtr_seq[:val_start], ytr_seq[:val_start]
XvaF, yvaF = Xtr_seq[val_start:], ytr_seq[val_start:]

# We'll recreate loaders per run because batch_size changes
MAX_EPOCHS = 50
PATIENCE = 7

results = []
best_val_rmse = float("inf")
best_state = None
best_run_id = None
best_params = None
best_val_r2 = None

for i in range(len(top_runs)):
    r = top_runs.iloc[i]

    params = {
        "hidden_lstm":  int(r["hidden_lstm"]),
        "hidden_gru":   int(r["hidden_gru"]),
        "dense1":       int(r["dense1"]),
        "dense2":       int(r["dense2"]),
        "dropout":      float(r["dropout"]),
        "lr":           float(r["lr"]),
        "weight_decay": float(r["weight_decay"]),
        "batch_size":   int(r["batch_size"]),
        "grad_clip":    float(r["grad_clip"]),
    }

    run_id = int(r["run_id"])
    seed = int(r["seed"])
    csv_val_rmse = float(r["val_rmse"])
    csv_val_r2 = float(r["val_r2"])

    set_seed(seed)

    train_loaderF = make_loader(XtrF, ytrF, batch_size=params["batch_size"], shuffle=True)
    val_loaderF   = make_loader(XvaF, yvaF, batch_size=params["batch_size"], shuffle=False)

    model = LSTMGRU(
        n_features=Xtr_seq.shape[-1],
        hidden_lstm=params["hidden_lstm"],
        hidden_gru=params["hidden_gru"],
        dense1=params["dense1"],
        dense2=params["dense2"],
        dropout=params["dropout"],
    ).to(device)

    best_rmse_train = train_one_trial(
        model=model,
        train_loader=train_loaderF,
        val_loader=val_loaderF,
        lr=params["lr"],
        weight_decay=params["weight_decay"],
        grad_clip=params["grad_clip"],
        max_epochs=MAX_EPOCHS,
        patience=PATIENCE
    )

    # compute RMSE + R2 on val at the loaded-best state
    yva_true, yva_pred = predict_loader(model, val_loaderF)
    val_rmse_retrain = rmse_np(yva_true, yva_pred)
    val_r2_retrain = r2_np(yva_true, yva_pred)


    out = {
        "rank": i+1,
        "run_id": run_id,
        "seed": seed,
        "csv_val_rmse": csv_val_rmse,
        "csv_val_r2": csv_val_r2,
        "retrain_val_rmse": float(val_rmse_retrain),
        "retrain_val_r2": float(val_r2_retrain),
        **params
    }
    results.append(out)

    print(f"\n[{i+1}/{TOPK}] run_id={run_id} seed={seed}")
    print("params:", params)
    print(f"csv val_rmse={csv_val_rmse:.6f} csv val_r2={csv_val_r2:.6f} | retrain val_rmse={val_rmse_retrain:.6f} retrain val_r2={val_r2_retrain:.6f}")

    # keep best retrained model (by lowest RMSE)
    if val_rmse_retrain < best_val_rmse:
        best_val_rmse = float(val_rmse_retrain)
        best_val_r2 = float(val_r2_retrain)
        best_state = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}
        best_run_id = run_id
        best_params = dict(params)

    del model
    if torch.cuda.is_available():
        torch.cuda.empty_cache()

results_df = pd.DataFrame(results).sort_values("retrain_val_rmse", ascending=True)
print("\nSUMMARY (sorted by retrain_val_rmse):")
display(results_df)

print("\nCHOSEN BEST (by retrain_val_rmse): run_id =", best_run_id,
      "val_rmse =", best_val_rmse, "val_r2 =", best_val_r2)
best = best_params

final_model = LSTMGRU(
    n_features=Xtr_seq.shape[-1],
    hidden_lstm=best["hidden_lstm"],
    hidden_gru=best["hidden_gru"],
    dense1=best["dense1"],
    dense2=best["dense2"],
    dropout=best["dropout"],
).to(device)

final_model.load_state_dict(best_state)
# Out:
# Top runs loaded: 10
#    run_id  seed  val_rmse    val_r2  hidden_lstm  hidden_gru  dense1  dense2  \
# 0     397   439  0.077059  0.117007           64         256     128      16
# 1      76   118  0.077827  0.099318           64          64      64      32
# 2     187   229  0.077892  0.097808           64         128      32      64
# 3     235   277  0.078137  0.092132           64         128      64      64
# 4     348   390  0.078521  0.083180           64         256      64      16
# 5     368   410  0.078798  0.076706           64         256      64      32
# 6     169   211  0.078844  0.075623           64         128      32      32
# 7     350   392  0.078855  0.075362           64         256      64      16
# 8     390   432  0.079076  0.070169           64         256     128      16
# 9     312   354  0.079434  0.061750           64         256      32      32
#
#    dropout      lr  weight_decay  batch_size  grad_clip
# 0      0.2  0.0010      0.000001          64        1.0
# 1      0.2  0.0005      0.000100         128        1.0
# 2      0.2  0.0005      0.000100          64        1.0
# 3      0.2  0.0005      0.000100          64        1.0
# 4      0.2  0.0005      0.000100         128        1.0
# 5      0.2  0.0010      0.000100         128        1.0
# 6      0.2  0.0005      0.000001          64        1.0
# 7      0.2  0.0010      0.000001         128        1.0
# 8      0.0  0.0010      0.000001         128        1.0
# 9      0.0  0.0010      0.000100         128        1.0
# [1/10] run_id=397 seed=439
# params: {'hidden_lstm': 64, 'hidden_gru': 256, 'dense1': 128, 'dense2': 16, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# csv val_rmse=0.077059 csv val_r2=0.117007 | retrain val_rmse=0.077059 retrain val_r2=0.117007
#
# [2/10] run_id=76 seed=118
# params: {'hidden_lstm': 64, 'hidden_gru': 64, 'dense1': 64, 'dense2': 32, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# csv val_rmse=0.077827 csv val_r2=0.099318 | retrain val_rmse=0.077827 retrain val_r2=0.099318
#
# [3/10] run_id=187 seed=229
# params: {'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 32, 'dense2': 64, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# csv val_rmse=0.077892 csv val_r2=0.097808 | retrain val_rmse=0.077892 retrain val_r2=0.097808
#
# [4/10] run_id=235 seed=277
# params: {'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 64, 'dense2': 64, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 64, 'grad_clip': 1.0}
# csv val_rmse=0.078137 csv val_r2=0.092132 | retrain val_rmse=0.078137 retrain val_r2=0.092132
#
# [5/10] run_id=348 seed=390
# params: {'hidden_lstm': 64, 'hidden_gru': 256, 'dense1': 64, 'dense2': 16, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# csv val_rmse=0.078521 csv val_r2=0.083180 | retrain val_rmse=0.078521 retrain val_r2=0.083180
#
# [6/10] run_id=368 seed=410
# params: {'hidden_lstm': 64, 'hidden_gru': 256, 'dense1': 64, 'dense2': 32, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# csv val_rmse=0.078798 csv val_r2=0.076706 | retrain val_rmse=0.078798 retrain val_r2=0.076706
#
# [7/10] run_id=169 seed=211
# params: {'hidden_lstm': 64, 'hidden_gru': 128, 'dense1': 32, 'dense2': 32, 'dropout': 0.2, 'lr': 0.0005, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}
# csv val_rmse=0.078844 csv val_r2=0.075623 | retrain val_rmse=0.078844 retrain val_r2=0.075623
#
# [8/10] run_id=350 seed=392
# params: {'hidden_lstm': 64, 'hidden_gru': 256, 'dense1': 64, 'dense2': 16, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# csv val_rmse=0.078855 csv val_r2=0.075362 | retrain val_rmse=0.078855 retrain val_r2=0.075362
#
# [9/10] run_id=390 seed=432
# params: {'hidden_lstm': 64, 'hidden_gru': 256, 'dense1': 128, 'dense2': 16, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 128, 'grad_clip': 1.0}
# csv val_rmse=0.079076 csv val_r2=0.070169 | retrain val_rmse=0.079076 retrain val_r2=0.070169
#
# [10/10] run_id=312 seed=354
# params: {'hidden_lstm': 64, 'hidden_gru': 256, 'dense1': 32, 'dense2': 32, 'dropout': 0.0, 'lr': 0.001, 'weight_decay': 0.0001, 'batch_size': 128, 'grad_clip': 1.0}
# csv val_rmse=0.079434 csv val_r2=0.061750 | retrain val_rmse=0.079434 retrain val_r2=0.061750
#
# SUMMARY (sorted by retrain_val_rmse):
#    rank  run_id  seed  csv_val_rmse  csv_val_r2  retrain_val_rmse  \
# 0     1     397   439      0.077059    0.117007          0.077059
# 1     2      76   118      0.077827    0.099318          0.077827
# 2     3     187   229      0.077892    0.097808          0.077892
# 3     4     235   277      0.078137    0.092132          0.078137
# 4     5     348   390      0.078521    0.083180          0.078521
# 5     6     368   410      0.078798    0.076706          0.078798
# 6     7     169   211      0.078844    0.075623          0.078844
# 7     8     350   392      0.078855    0.075362          0.078855
# 8     9     390   432      0.079076    0.070169          0.079076
# 9    10     312   354      0.079434    0.061750          0.079434
#
#    retrain_val_r2  hidden_lstm  hidden_gru  dense1  dense2  dropout      lr  \
# 0        0.117007           64         256     128      16      0.2  0.0010
# 1        0.099318           64          64      64      32      0.2  0.0005
# 2        0.097808           64         128      32      64      0.2  0.0005
# 3        0.092132           64         128      64      64      0.2  0.0005
# 4        0.083180           64         256      64      16      0.2  0.0005
# 5        0.076706           64         256      64      32      0.2  0.0010
# 6        0.075623           64         128      32      32      0.2  0.0005
# 7        0.075362           64         256      64      16      0.2  0.0010
# 8        0.070169           64         256     128      16      0.0  0.0010
# 9        0.061750           64         256      32      32      0.0  0.0010
#
#    weight_decay  batch_size  grad_clip
# 0      0.000001          64        1.0
# 1      0.000100         128        1.0
# 2      0.000100          64        1.0
# 3      0.000100          64        1.0
# 4      0.000100         128        1.0
# 5      0.000100         128        1.0
# 6      0.000001          64        1.0
# 7      0.000001         128        1.0
# 8      0.000001         128        1.0
# 9      0.000100         128        1.0
# CHOSEN BEST (by retrain_val_rmse): run_id = 397 val_rmse = 0.07705909013748169 val_r2 = 0.11700719594955444
# <All keys matched successfully>

# %%
print("Evaluating best_run_id:", best_run_id)
print("Evaluating best params:", best)
# Out:
# Evaluating best_run_id: 397
# Evaluating best params: {'hidden_lstm': 64, 'hidden_gru': 256, 'dense1': 128, 'dense2': 16, 'dropout': 0.2, 'lr': 0.001, 'weight_decay': 1e-06, 'batch_size': 64, 'grad_clip': 1.0}

# %% [markdown]
# ## Evaluation of the Model

# %%
#cell 12: test evaluation + save metrics
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

def mda(y_true, y_pred):
    yt = np.asarray(y_true)
    yp = np.asarray(y_pred)
    true_dir = (yt > 0).astype(int)
    pred_dir = (yp > 0).astype(int)
    return float(np.mean(true_dir == pred_dir))

def eval_metrics(y_true, y_pred):
    return {
        "MAE":  float(mean_absolute_error(y_true, y_pred)),
        "RMSE": float(np.sqrt(mean_squared_error(y_true, y_pred))),
        "R2":   float(r2_score(y_true, y_pred)),
        "MDA":  float(mda(y_true, y_pred)),
    }

test_loader = make_loader(Xte_seq, yte_seq, batch_size=256, shuffle=False)
y_true_te, y_pred_te = predict_loader(final_model, test_loader)

metrics = eval_metrics(y_true_te, y_pred_te)
print(metrics)

out_path = PROC_DIR / "phase2_metrics.csv"
row = {
    "model": f"LSTM_GRU_PCA_GridSearch_RMSE_run{best_run_id}",
    **metrics
}

if out_path.exists():
    prev = pd.read_csv(out_path)
    new = pd.concat([prev, pd.DataFrame([row])], ignore_index=True)
else:
    new = pd.DataFrame([row])

new.to_csv(out_path, index=False)
print("saved:", out_path)
display(new.tail(50))
# Out:
# {'MAE': 0.06309177726507187, 'RMSE': 0.07652710040284857, 'R2': -0.37250685691833496, 'MDA': 0.48863636363636365}
# saved: /media/workhorse/Windows/MyWorkPlace/Projects/StockPredictor/data/processed/phase2_metrics.csv
#                                    model       MAE      RMSE        R2  \
# 0                    LSTM_GRU_PCA_Optuna  0.010902  0.016297  0.004003
# 1                    LSTM_GRU_PCA_Optuna  0.011765  0.017072 -0.093003
# 2                    LSTM_GRU_PCA_Optuna  0.010906  0.016367 -0.004573
# 3                    LSTM_GRU_PCA_Optuna  0.011357  0.016551 -0.027400
# 4                    LSTM_GRU_PCA_Optuna  0.011533  0.016739 -0.050865
# 5                    LSTM_GRU_PCA_Optuna  0.011830  0.016986 -0.082041
# 6   SimpleLSTM_NoPCA_TargetScaled_Optuna  0.011583  0.017131 -0.100588
# 7                    LSTM_GRU_PCA_Optuna  0.014199  0.019408 -0.412698
# 8                    LSTM_GRU_PCA_Optuna  0.014824  0.019441 -0.417465
# 9                    LSTM_GRU_PCA_Optuna  0.012307  0.017530 -0.152430
# 10                   LSTM_GRU_PCA_Optuna  0.011463  0.016606 -0.034239
# 11                   LSTM_GRU_PCA_Optuna  0.011463  0.016606 -0.034239
# 12                   LSTM_GRU_PCA_Optuna  0.011463  0.016606 -0.034239
# 13         LSTM_GRU_PCA_GridSearch_run27  0.011331  0.016532 -0.025043
# 14         LSTM_GRU_PCA_GridSearch_run27  0.054176  0.067623 -0.071715
# 15         LSTM_GRU_PCA_GridSearch_run27  0.054176  0.067623 -0.071715
# 16        LSTM_GRU_PCA_GridSearch_run772  0.054734  0.066905 -0.049050
# 17        LSTM_GRU_PCA_GridSearch_run772  0.054734  0.066905 -0.049050
# 18        LSTM_GRU_PCA_GridSearch_run772  0.000990  0.001210 -0.049050
# 19        LSTM_GRU_PCA_GridSearch_run772  0.054734  0.066905 -0.049050
# 20        LSTM_GRU_PCA_GridSearch_run397  0.063092  0.076527 -0.372507
# 21        LSTM_GRU_PCA_GridSearch_run397  0.063092  0.076527 -0.372507
# 22   LSTM_GRU_PCA_GridSearch_RMSE_run397  0.063092  0.076527 -0.372507
#
#          MDA
# 0   0.530645
# 1   0.553226
# 2   0.543548
# 3   0.470968
# 4   0.485484
# 5   0.509677
# 6   0.482258
# 7   0.543548
# 8   0.453226
# 9   0.506452
# 10  0.477419
# 11  0.477419
# 12  0.477419
# 13  0.508065
# 14  0.566558
# 15  0.566558
# 16  0.503247
# 17  0.503247
# 18  0.801948
# 19  0.503247
# 20  0.488636
# 21  0.488636
# 22  0.488636

# %% [markdown]
# ## Saving the model artifacts

# %%
#cell 13: save phase 2 artifacts
import joblib
import json

art_dir = PROC_DIR / "phase2_artifacts"
art_dir.mkdir(parents=True, exist_ok=True)

#save preprocessing objects
joblib.dump(scaler, art_dir / "scaler.joblib")
joblib.dump(pca,    art_dir / "pca.joblib")

#save model weights
torch.save(final_model.state_dict(), art_dir / "lstm_gru_pca_weights.pt")

#save grid best params
with open(art_dir / "grid_best_params.json", "w") as f:
    json.dump(best, f, indent=2)

# also save the full grid run log snapshot
grid_path = PROC_DIR / "phase2_gridsearch_runs_rmse.csv"
if grid_path.exists():
    pd.read_csv(grid_path).to_csv(art_dir / "gridsearch_runs.csv", index=False)

#save test predictions with dates aligned to test targets
test_dates = test_df["date"].values
test_dates_seq = test_dates

pred_df = pd.DataFrame({
    "date": pd.to_datetime(test_dates_seq),
    "y_true": y_test.values.astype(float),
    "y_pred": y_pred_te.astype(float)
})

pred_df.to_csv(art_dir / "test_predictions.csv", index=False)

print("saved artifacts to:", art_dir)
display(pred_df.head())
display(pred_df.tail())
# Out:
# saved artifacts to: /media/workhorse/Windows/MyWorkPlace/Projects/StockPredictor/data/processed/phase2_artifacts
#         date    y_true    y_pred
# 0 2023-05-11  0.042041  0.002842
# 1 2023-05-12  0.062991  0.000071
# 2 2023-05-15  0.063277  0.005354
# 3 2023-05-16  0.066763  0.007906
# 4 2023-05-17  0.074302  0.010474
#           date    y_true    y_pred
# 611 2025-12-17 -0.061874  0.018012
# 612 2025-12-18 -0.098327  0.018318
# 613 2025-12-19 -0.099907  0.018826
# 614 2025-12-22 -0.087169  0.020319
# 615 2025-12-23 -0.093535  0.024743

# %%
# DIAG A: target distribution + baseline metrics (VAL + TEST)

def summarize_y(name, y):
    y = np.asarray(y).astype(float)
    print(f"\n{name}: n={len(y)} mean={y.mean():.6f} std={y.std():.6f} min={y.min():.6f} max={y.max():.6f}")

def metrics_block(name, y_true, y_pred):
    return {
        "set": name,
        "MAE": float(np.mean(np.abs(y_true - y_pred))),
        "RMSE": rmse_np(y_true, y_pred),
        "R2": r2_np(y_true, y_pred),
        "pred_std": float(np.std(y_pred)),
        "true_std": float(np.std(y_true)),
        "std_ratio": float(np.std(y_pred) / (np.std(y_true) + 1e-12)),
        "corr": float(np.corrcoef(y_true, y_pred)[0,1]) if np.std(y_pred) > 0 and np.std(y_true) > 0 else np.nan
    }

val_loader_dbg  = make_loader(Xva, yva, batch_size=256, shuffle=False)
test_loader_dbg = make_loader(Xte_seq, yte_seq, batch_size=256, shuffle=False)

yva_true, _ = predict_loader(final_model, val_loader_dbg)   # y_true from loader
yte_true, _ = predict_loader(final_model, test_loader_dbg)

summarize_y("VAL y", yva_true)
summarize_y("TEST y", yte_true)

# Baselines
val_mean = float(np.mean(yva_true))
test_mean = float(np.mean(yte_true))

yhat0_val  = np.zeros_like(yva_true)
yhatm_val  = np.full_like(yva_true, val_mean)

yhat0_test = np.zeros_like(yte_true)
yhatm_test = np.full_like(yte_true, test_mean)

print("\nBASELINES:")
print(metrics_block("VAL  predict_0", yva_true, yhat0_val))
print(metrics_block("VAL  predict_mean(val)", yva_true, yhatm_val))
print(metrics_block("TEST predict_0", yte_true, yhat0_test))
print(metrics_block("TEST predict_mean(test)", yte_true, yhatm_test))
# Out:
# VAL y: n=241 mean=0.018734 std=0.082006 min=-0.167054 max=0.211720
#
# TEST y: n=616 mean=0.009798 std=0.065322 min=-0.247505 max=0.187641
#
# BASELINES:
# {'set': 'VAL  predict_0', 'MAE': 0.07054489850997925, 'RMSE': 0.0841185674071312, 'R2': -0.052187442779541016, 'pred_std': 0.0, 'true_std': 0.08200594037771225, 'std_ratio': 0.0, 'corr': nan}
# {'set': 'VAL  predict_mean(val)', 'MAE': 0.0676782876253128, 'RMSE': 0.08200594037771225, 'R2': 0.0, 'pred_std': 0.0, 'true_std': 0.08200594037771225, 'std_ratio': 0.0, 'corr': nan}
# {'set': 'TEST predict_0', 'MAE': 0.05364672467112541, 'RMSE': 0.06605246663093567, 'R2': -0.022497057914733887, 'pred_std': 0.0, 'true_std': 0.06532178074121475, 'std_ratio': 0.0, 'corr': nan}
# {'set': 'TEST predict_mean(test)', 'MAE': 0.0523521825671196, 'RMSE': 0.06532178074121475, 'R2': 0.0, 'pred_std': 9.313225746154785e-10, 'true_std': 0.06532178074121475, 'std_ratio': 1.4257458446989388e-08, 'corr': nan}
# /media/workhorse/Windows/MyWorkPlace/ml_venv/lib/python3.12/site-packages/numpy/lib/function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /media/workhorse/Windows/MyWorkPlace/ml_venv/lib/python3.12/site-packages/numpy/lib/function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]

# %%
# DIAG B: model metrics on VAL + TEST
yva_true, yva_pred = predict_loader(final_model, val_loader_dbg)
yte_true, yte_pred = predict_loader(final_model, test_loader_dbg)

print("\nMODEL:")
print(metrics_block("VAL  model", yva_true, yva_pred))
print(metrics_block("TEST model", yte_true, yte_pred))
# Out:
# MODEL:
# {'set': 'VAL  model', 'MAE': 0.06257263571023941, 'RMSE': 0.07705909013748169, 'R2': 0.11700719594955444, 'pred_std': 0.032512445002794266, 'true_std': 0.08200594037771225, 'std_ratio': 0.3964645104080058, 'corr': 0.35119836434674806}
# {'set': 'TEST model', 'MAE': 0.06309177726507187, 'RMSE': 0.07652710378170013, 'R2': -0.37250685691833496, 'pred_std': 0.03242636099457741, 'true_std': 0.06532178074121475, 'std_ratio': 0.49640962977639086, 'corr': -0.0319846324521166}
